# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import timedelta
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout, Flatten, Input, Attention
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.losses import Huber
from tensorflow.keras import backend as K
from xgboost import XGBRegressor
from keras.regularizers import l2, l1
from scipy.stats import pearsonr, spearmanr
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBRegressor
import shap
import seaborn as sns

# %% [markdown]
# ### UTILITY FUNCTIONS

# %%
IBM_BLUE = "#648FFF"
IBM_PURPLE = "#785EF0"
IBM_PINK = "#DC267F"
IBM_ORANGE = "#FE6100"
IBM_YELLOW = "#FFB000"

# %%
# Define the columns for each normalization
flow_columns = ['conchos_flow', 'alv_flow']
storage_columns = ['lb_storage', 'ami_storage']
flood_columns = ['lb_flood', 'ami_flood', 'falc_flood']
static_columns = ['ami_conservation','falc_conservation','lb_conservation',
                    'ami_dead','lb_dead','falc_dead']  # Assuming no static characteristics for now
precip_columns = ['precipitation','tc']
deliveries_column = 'deliveries'  # Specify the target variable for deliveries

# %%
### IBWC file reader
def clean_IBWC_csvs(path,dropcols='End of Interval (UTC-06:00)',value_current="Average (TCM)",skiphead=4,skipfoot=1,
                    value_target="storage",datecol="Start of Interval (UTC-06:00)",start_date='1962-01-01',end_date='2023-12-31'):
    """
    Cleans a csv dataset from the IBWC
    """
    dat = pd.read_csv(path,skiprows=skiphead,skipfooter=skipfoot,engine='python')
    try:
        dat.drop(dropcols, inplace=True, axis='columns')
    except:
        print(f'No columns to drop, continuing...')
    dat[datecol] = pd.to_datetime(dat[datecol])
    dat.rename(columns={datecol:"date", value_current:value_target}, inplace=True)
    dat["date"] = pd.to_datetime(dat["date"])
    dat = dat[(dat['date'] >= start_date) & (dat['date'] <= end_date)]
    return dat

# %%
def clean_daymet_data(path,skiphead=6,start_date='1962-01-01',end_date='2023-12-31'):
    dat = pd.read_csv(path,skiprows=skiphead,engine='python')
    dat['date'] = pd.to_datetime(dat['year'].astype(str) + dat['yday'].astype(int).astype(str), format='%Y%j')
    print(dat.columns)
    dat = dat[(dat['date'] >= start_date) & (dat['date'] <= end_date)]
    dat = dat.drop(['yday','year','dayl (s)'],axis='columns')
    return dat

# %%
clean_daymet_data("/Users/laratobias-tarsh/Documents/SEAS_hydro/deliveries/daymet_data/daymet_conchos.csv")
# Out:
# Index(['year', 'yday', 'dayl (s)', 'prcp (mm/day)', 'srad (W/m^2)',
#        'swe (kg/m^2)', 'tmax (deg c)', 'tmin (deg c)', 'vp (Pa)', 'date'],
#       dtype='object')
#        prcp (mm/day)  srad (W/m^2)  swe (kg/m^2)  tmax (deg c)  tmin (deg c)  \
# 0               0.00        342.70           0.0         20.35         -1.45
# 1               0.00        351.36           0.0         21.47         -1.45
# 2               0.00        273.41           0.0         15.64          0.56
# 3               0.00        367.83           0.0         21.83         -3.37
# 4               0.00        347.27           0.0         20.86         -1.12
# ...              ...           ...           ...           ...           ...
# 14960           0.00        372.43           0.0         20.80         -6.88
# 14961           0.00        360.90           0.0         23.85         -1.74
# 14962           0.00        358.12           0.0         23.71         -1.36
# 14963           0.00        349.80           0.0         27.62          3.51
# 14964          26.13        189.30           0.0         18.50          4.10
#
#        vp (Pa)       date
# 0       381.22 1980-01-01
# 1       369.43 1980-01-02
# 2       528.92 1980-01-03
# 3       308.82 1980-01-04
# 4       383.39 1980-01-05
# ...        ...        ...
# 14960   122.81 2020-12-26
# 14961   185.81 2020-12-27
# 14962   191.48 2020-12-28
# 14963   278.69 2020-12-29
# 14964   423.03 2020-12-30
#
# [14965 rows x 7 columns]

# %%
def normalize_data(df, flow_columns, storage_columns, flood_columns, static_columns, precip_columns, deliveries_column=None):
    """
    Normalize the dataframe with the following steps:
    1. Min-Max scaling for flow variables.
    2. Normalize storage relative to flood capacity.
    3. Standardize precipitation and other continuous features.
    4. Normalize deliveries (target variable) if provided.

    Also, returns the necessary values for later denormalization (scalers, flood capacities).

    Parameters:
    df (pd.DataFrame): The input dataframe containing raw data.
    flow_columns (list): List of columns for flow variables to be normalized.
    storage_columns (list): List of columns for storage variables to be normalized.
    flood_columns (list): List of columns for flood capacity for each reservoir.
    static_columns (list): List of columns for static reservoir characteristics to be normalized.
    precip_columns (list): List of columns for precipitation and other continuous variables to be standardized.
    deliveries_column (str, optional): The column for target variable deliveries to be normalized.

    Returns:
    pd.DataFrame: The normalized dataframe.
    dict: A dictionary containing values needed for denormalization (scalers, flood capacities).
    """
    # --- Flow normalization (Min-Max Scaling) ---
    flow_scaler = MinMaxScaler()
    df[flow_columns] = flow_scaler.fit_transform(df[flow_columns])

    # --- Storage normalization (relative to flood capacity) ---
    flood_capacities = {col: df[col].copy() for col in flood_columns}

    # Normalize storage by dividing by flood capacity
    for storage_col, flood_col in zip(storage_columns, flood_columns):
        df[storage_col] = df[storage_col] / df[flood_col]

    # --- Static reservoir characteristics normalization (relative to flood capacity) ---
    for col in static_columns:
        reservoir_prefix = col.split('_')[0]
        df[col] = df[col] / df[f'{reservoir_prefix}_flood']  # Normalize by flood capacity

    # --- Set flood columns to 1 (as the reference) ---
    for flood_col in flood_columns:
        df[flood_col] = 1  # Set flood capacity to 1 for all rows

    # --- Precipitation and other continuous variables (Standardization) ---
    std_scaler = StandardScaler()
    df[precip_columns] = std_scaler.fit_transform(df[precip_columns])

    # --- Normalize Deliveries (target variable) if provided ---
    deliveries_scaler = None
    if deliveries_column:
        deliveries_scaler = MinMaxScaler()  # or StandardScaler() depending on your preference
        df[deliveries_column] = deliveries_scaler.fit_transform(df[[deliveries_column]])

    # Prepare the dictionary for denormalization
    denormalization_info = {
        'flow_scaler': flow_scaler,
        'flood_capacities': flood_capacities,
        'std_scaler': std_scaler,
        'deliveries_scaler': deliveries_scaler
    }

    return df, denormalization_info

# %%
def denormalize(normalized_deliveries, denormalization_info):
    """
    Denormalize the deliveries column based on the scaler information.
    
    Parameters:
    normalized_deliveries (array-like): The normalized deliveries to be denormalized.
    denormalization_info (dict): The dictionary containing the scaler for deliveries.
    
    Returns:
    array: The denormalized deliveries values.
    """
    deliveries_scaler = denormalization_info.get('deliveries_scaler')
    if deliveries_scaler is None:
        raise ValueError("No scaler found for deliveries in denormalization_info.")
    
    # Reshape to 2D as required by the scaler
    normalized_deliveries = normalized_deliveries.reshape(-1, 1)
    
    # Denormalize deliveries
    denormalized_deliveries = deliveries_scaler.inverse_transform(normalized_deliveries)
    
    return denormalized_deliveries

# %%
def process_data(df, target_column='flow', lookback_period=100, lag_dict=None, debug=0, trainyrs=5, valyrs=3):
    if debug < 1:
        print("Initial Data:")
        print(df.head())

    data = df.copy()
    data, denorm = normalize_data(data,flow_columns, storage_columns, flood_columns, static_columns, precip_columns, deliveries_column)

    # Ensure the date column is datetime
    data['date'] = pd.to_datetime(data['date'])
  
    for var, lag in lag_dict.items():
        if isinstance(lag,int):
            for i in range(1, lag + 1):
                data[f'{var}_lag{i}'] = data[var].shift(i)
        else:
            for i in lag:
                data[f'{var}_lag{i}'] = data[var].shift(i)

    # Drop rows with NaN values due to lagging
    data = data.dropna()

    # Select features dynamically based on the lag_dict
    feature_columns = []
    for var, lag in lag_dict.items():
        if isinstance(lag,int):
            feature_columns.extend([f'{var}_lag{i}' for i in range(1, lag + 1)])
        else:
            feature_columns.extend([f'{var}_lag{i}' for i in lag])

    if debug > 1:
        print("\nFeature Columns Selected:")
        print(feature_columns)

    # Define the features and target (y)
    features = data[feature_columns]
    target = data[target_column]

    if debug > 1:
        print("\nFeatures DataFrame:")
        print(features.head())
        
        print("\nTarget Series:")
        print(target.head())

    # Normalize dynamic features
    feature_means = features.mean(axis=0)
    feature_stds = features.std(axis=0)
    features_scaled = (features - feature_means) / feature_stds

    # Normalize target variable
    target_mean = target.mean()
    target_std = target.std()
    target_scaled = (target - target_mean) / target_std

    if debug > 1:
        print("\nNormalized Features DataFrame:")
        print(features_scaled.head())
        
        print("\nNormalized Target Series:")
        print(target_scaled.head())

    # Convert to numpy arrays
    features_scaled = features.values
    target_scaled = target.values

    X = []
    y = []

    for i in range(lookback_period, len(features_scaled)):
        X.append(features_scaled[i-lookback_period:i])
        y.append(target_scaled[i])

    X = np.array(X)
    y = np.array(y)

    # Define the indices for the desired train/val/test period
    start_date = data['date'].iloc[0]
    train_end_date = start_date + timedelta(days=365.25*trainyrs)
    val_end_date = train_end_date + timedelta(days=365.25*valyrs)

    train_end_index = data[data['date'] <= train_end_date].index[-1] - lookback_period + 1
    val_end_index = data[data['date'] <= val_end_date].index[-1] - lookback_period + 1

    X_train, X_val, X_test = X[:train_end_index], X[train_end_index:val_end_index], X[val_end_index:]
    y_train, y_val, y_test = y[:train_end_index], y[train_end_index:val_end_index], y[val_end_index:]

    # Extract dates for train, validation, and test sets
    train_dates = data['date'].iloc[:train_end_index + lookback_period]
    val_dates = data['date'].iloc[train_end_index + lookback_period:val_end_index + lookback_period]
    test_dates = data['date'].iloc[val_end_index + lookback_period:]

    dates_dict = {
        'train_dates': train_dates,
        'val_dates': val_dates,
        'test_dates': test_dates
    }

    if debug > 1:
        print("\nFirst 5 rows of Training Data (X_train):")
        print(X_train[:5])
        print("\nFirst 5 rows of Training Targets (y_train):")
        print(y_train[:5])

        print("\nTraining Date Range:")
        print(train_dates.iloc[0], "to", train_dates.iloc[-1])

        print("\nValidation Date Range:")
        print(val_dates.iloc[0], "to", val_dates.iloc[-1])

        print("\nTest Date Range:")
        print(test_dates.iloc[0], "to", test_dates.iloc[-1])

    return X_train, X_val, X_test, y_train, y_val, y_test, denorm, dates_dict, feature_columns

# %%
def process_data_for_xgboost(df, target_column='flow', lag_dict=None, debug=0, trainyrs=5, valyrs=3):
    # Ensure the date column is datetime
    df['date'] = pd.to_datetime(df['date'])

    # Add lagged features dynamically based on the specified lag_dict
    data = df.copy()
    data, denorm = normalize_data(data,flow_columns, storage_columns, flood_columns, static_columns, precip_columns, deliveries_column)

    for var, lag in lag_dict.items():
        if isinstance(lag,int):
            for i in range(1, lag + 1):
                data[f'{var}_lag{i}'] = data[var].shift(i)
        else:
            for i in lag:
                data[f'{var}_lag{i}'] = data[var].shift(i)

    # Drop rows with NaN values due to lagging
    data = data.dropna()

    # Select features dynamically based on the lag_dict
    feature_columns = []
    for var, lag in lag_dict.items():
        if isinstance(lag,int):
            feature_columns.extend([f'{var}_lag{i}' for i in range(1, lag + 1)])
        else:
            feature_columns.extend([f'{var}_lag{i}' for i in lag])

    if debug:
        print("\nFeature Columns Selected:")
        print(feature_columns)

    # Extract features and target
    features = data[feature_columns]
    target = data[target_column]

    # Convert to numpy arrays
    features_scaled = features.values
    target_scaled = target.values

    # Define the indices for the desired train/val/test period
    start_date = data['date'].iloc[0]
    train_end_date = start_date + timedelta(days=365.25 * trainyrs)
    val_end_date = train_end_date + timedelta(days=365.25 * valyrs)

    train_end_index = data[data['date'] <= train_end_date].index[-1]
    val_end_index = data[data['date'] <= val_end_date].index[-1]

    X_train, X_val, X_test = features_scaled[:train_end_index + 1], features_scaled[train_end_index + 1:val_end_index + 1], features_scaled[val_end_index + 1:]
    y_train, y_val, y_test = target_scaled[:train_end_index + 1], target_scaled[train_end_index + 1:val_end_index + 1], target_scaled[val_end_index + 1:]

    # Extract dates for train, validation, and test sets
    train_dates = data['date'][:train_end_index + 1]
    val_dates = data['date'][train_end_index + 1:val_end_index + 1]
    test_dates = data['date'][val_end_index + 1:]


    dates_dict = {
        'train_dates': train_dates,
        'val_dates': val_dates,
        'test_dates': test_dates
    }

    if debug:
        print(f"\nFirst 5 rows of Training Data (X_train):\n{X_train[:5]}")
        print(f"\nFirst 5 rows of Training Targets (y_train):\n{y_train[:5]}")
        print(f"\nTraining Date Range: {train_dates.iloc[0]} to {train_dates.iloc[-1]}")
        print(f"\nValidation Date Range: {val_dates.iloc[0]} to {val_dates.iloc[-1]}")
        print(f"\nTest Date Range: {test_dates.iloc[0]} to {test_dates.iloc[-1]}")

    return X_train, X_val, X_test, y_train, y_val, y_test, denorm, dates_dict, feature_columns

# %%
def persistence_model(y_train, y_test):
    # Use the last value of y_train as the persistence prediction for the first value of y_test
    first_prediction = y_train[-1]
    predictions = np.zeros_like(y_test)
    
    # Setting the first prediction
    predictions[0] = first_prediction
    
    # All subsequent predictions use the previous time step value from y_test
    for i in range(1, len(y_test)):
        predictions[i] = y_test[i-1]
    
    return predictions

# %%
def nash_sutcliffe_efficiency(observed, predicted):
    return 1 - (np.sum((observed - predicted) ** 2) / np.sum((observed - np.mean(observed)) ** 2))

def kling_gupta_efficiency(observed, predicted):
    cc = np.corrcoef(observed, predicted)[0, 1]
    alpha = np.std(predicted) / np.std(observed)
    beta = np.mean(predicted) / np.mean(observed)
    return 1 - np.sqrt((cc - 1) ** 2 + (alpha - 1) ** 2 + (beta - 1) ** 2)

def rmse_95th_percentile(y_true, y_pred):
    threshold = np.percentile(y_true, 95)
    extreme_indices = y_true > threshold
    if np.sum(extreme_indices) > 0:  # Ensure there are values above the threshold
        return np.sqrt(mean_squared_error(y_true[extreme_indices], y_pred[extreme_indices]))
    else:
        return np.nan  # If no values exceed the threshold, return NaN

# %%
def evaluate_persistence_model(y_train, y_test, denorm_dict):
    # Get predictions using persistence model
    predictions = persistence_model(y_train, y_test)
    
    # Denormalize predictions and target
    denorm_predictions = denormalize(predictions.flatten(), denorm_dict).flatten()
    denorm_y_test = denormalize(y_test, denorm_dict).flatten()

    # Calculate metrics
    mae = mean_absolute_error(denorm_y_test, denorm_predictions)
    rmse = np.sqrt(mean_squared_error(denorm_y_test, denorm_predictions))
    pearson_corr, _ = pearsonr(denorm_y_test, denorm_predictions)
    spearman_corr, _ = spearmanr(denorm_y_test, denorm_predictions)
    nse = nash_sutcliffe_efficiency(denorm_y_test, denorm_predictions)
    kge = kling_gupta_efficiency(denorm_y_test, denorm_predictions)
    
    # Collect metrics in a dictionary
    metrics = {
        'MAE': mae,
        'RMSE': rmse,
        'Pearson_Correlation': pearson_corr,
        'Spearman_Correlation': spearman_corr,
        'Nash_Sutcliffe_Efficiency': nse,
        'Kling_Gupta_Efficiency': kge,
    }
    
    return denorm_predictions, denorm_y_test, metrics

# %%
def train_evaluate_xgboost_model(model, X_train, y_train, X_val, y_val, X_test, y_test, denorm_dict, n_estimators=1000, early_stopping_rounds=10):
    # Train model
    history = model.fit(X_train, y_train,
              eval_set=[(X_val, y_val)],
              verbose=False)
    
    # Evaluate model
    predictions = model.predict(X_test)
    
    # Denormalize predictions and target
    denorm_predictions = denormalize(predictions.flatten(), denorm_dict).flatten()
    denorm_y_test = denormalize(y_test, denorm_dict).flatten()
    
    # Calculate metrics
    mae = mean_absolute_error(denorm_y_test, denorm_predictions)
    rmse = np.sqrt(mean_squared_error(denorm_y_test, denorm_predictions))
    pearson_corr, _ = pearsonr(denorm_y_test, denorm_predictions)
    spearman_corr, _ = spearmanr(denorm_y_test, denorm_predictions)
    nse = nash_sutcliffe_efficiency(denorm_y_test, denorm_predictions)
    kge = kling_gupta_efficiency(denorm_y_test, denorm_predictions)
    
    # Collect metrics in a dictionary
    metrics = {
        'MAE': mae,
        'RMSE': rmse,
        'Pearson_Correlation': pearson_corr,
        'Spearman_Correlation': spearman_corr,
        'Nash_Sutcliffe_Efficiency': nse,
        'Kling_Gupta_Efficiency': kge,
    }
    
    return model, denorm_predictions, denorm_y_test, metrics

# %%
def evaluate_rf_model(model, X_train, y_train, X_val, y_val, X_test, y_test, denorm_dict):
    # Train model
    model.fit(X_train, y_train)
    
    # Predict on the test set
    predictions = model.predict(X_test)
    
    # Denormalize predictions and target
    denorm_predictions = denormalize(predictions.flatten(), denorm_dict).flatten()
    denorm_y_test = denormalize(y_test, denorm_dict).flatten()

    # Calculate metrics
    mae = mean_absolute_error(denorm_y_test, denorm_predictions)
    rmse = np.sqrt(mean_squared_error(denorm_y_test, denorm_predictions))
    pearson_corr, _ = pearsonr(denorm_y_test, denorm_predictions)
    spearman_corr, _ = spearmanr(denorm_y_test, denorm_predictions)
    nse = nash_sutcliffe_efficiency(denorm_y_test, denorm_predictions)
    kge = kling_gupta_efficiency(denorm_y_test, denorm_predictions)
    
    # Collect metrics in a dictionary
    metrics = {
        'MAE': mae,
        'RMSE': rmse,
        'Pearson_Correlation': pearson_corr,
        'Spearman_Correlation': spearman_corr,
        'Nash_Sutcliffe_Efficiency': nse,
        'Kling_Gupta_Efficiency': kge,
    }
    
    return model, denorm_predictions, denorm_y_test, metrics

# %%
### Model Training and Evaluation Functions
def train_evaluate_sequential(model, X_train, y_train, X_val, y_val, X_test, y_test, denorm_dict, epochs=30, batch_size=32,train=True):
    # Train model
    if train:
        history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val), verbose=0)
    
    # Evaluate model
    test_loss = model.evaluate(X_test, y_test, verbose=0)
    predictions = model.predict(X_test)
    
    # Denormalize predictions and target
    denorm_predictions = denormalize(predictions.flatten(), denorm_dict)
    denorm_y_test = denormalize(y_test, denorm_dict)
    
    # Calculate metrics
    mae = mean_absolute_error(denorm_y_test, denorm_predictions)
    rmse = np.sqrt(mean_squared_error(denorm_y_test, denorm_predictions))
    pearson_corr, _ = pearsonr(denorm_y_test, denorm_predictions)
    spearman_corr, _ = spearmanr(denorm_y_test, denorm_predictions)
    nse = nash_sutcliffe_efficiency(denorm_y_test, denorm_predictions)
    #kge = kling_gupta_efficiency(denorm_y_test, denorm_predictions)
    rmse_extreme = rmse_95th_percentile(denorm_y_test, denorm_predictions)

    metrics = {
        'MAE': mae,
        'RMSE': rmse,
        'Pearson_Correlation': pearson_corr,
        'Spearman_Correlation': spearman_corr,
        'Nash_Sutcliffe_Efficiency': nse,
        #'Kling_Gupta_Efficiency': kge,
        'RMSE_Extreme': rmse_extreme
    }
    
    
    return model, denorm_predictions, denorm_predictions, denorm_y_test, metrics

# %%
def integrated_gradients(model, X_input, baseline=None, num_steps=50):
    """
    Compute integrated gradients for a given model and input.
    Aggregates importance across all time steps to get per-feature importance.

    Parameters:
    - model: The trained model
    - X_input: The input instance for which we want to explain predictions
    - baseline: The baseline input (defaults to zeros)
    - num_steps: Number of steps to approximate the integral (higher = more accurate)

    Returns:
    - feature_importance: A vector containing the importance of each feature
    """
    if baseline is None:
        baseline = np.zeros_like(X_input)  # Use zeros as baseline
    
    # Convert inputs to numpy arrays
    X_input = np.array(X_input)
    baseline = np.array(baseline)
    
    # Initialize gradients
    X_input = tf.Variable(X_input, dtype=tf.float32)
    baseline = tf.Variable(baseline, dtype=tf.float32)

    # Initialize an array to store per-feature importance
    feature_importance = np.zeros(X_input.shape[2])  # Number of features

    # Interpolate between baseline and input and compute gradients
    for step in range(1, num_steps + 1):
        alpha = step / num_steps
        interpolated_input = baseline + alpha * (X_input - baseline)

        with tf.GradientTape() as tape:
            tape.watch(interpolated_input)
            model_output = model(interpolated_input)

        grads = tape.gradient(model_output, interpolated_input)

        # Sum gradients over time steps and batch, then average over all interpolation steps
        feature_importance += np.mean(grads.numpy(), axis=(0, 1)).flatten()  # Sum over time and batch axis

    # Average over the num_steps
    feature_importance /= num_steps
    return feature_importance

# %%
def plot_predictions(y_test,predictions,model_type,dates,color=IBM_PINK):

    fig = plt.figure(figsize=(14, 4))
    gs = fig.add_gridspec(1, 2, width_ratios=[2, 1])  # First plot takes up 2 units, second one takes 1 unit

    # Define the axes for the subplots
    ax = fig.add_subplot(gs[0])  # The time series plot (larger plot)
    ax1 = fig.add_subplot(gs[1])  # The 1:1 correlation scatter plot (smaller plot)

    ax.plot(dates['test_dates'],y_test, label='Observed',c='k')
    ax.plot(dates['test_dates'],predictions, label=f'{model_type} Predictions', linestyle='--',c=color)
    ax.legend()
    ax.set_title(f'{model_type} Predictions vs Observations',loc='left')
    ax.set_ylabel('Deliveries (MCM)')
    ax.set_xlabel('Time')
    ax.legend(frameon=False)


    # Correlation Scatter Plot
    ax1.scatter(y_test, predictions, alpha=0.6,c=color)
    # Plot the 1:1 line (identity line), which is the ideal case where predicted = observed
    ax1.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'k--', label="1:1 Line")

    # Set labels and title
    ax1.set_title('Correlation Scatter Plot',loc='left')
    ax1.set_xlabel('Observed Streamflow')
    ax1.set_ylabel('Predicted Streamflow')

# %%
def plot_integrated_grads(X_test,feature_names,model,model_type):
    X_test_instance = X_test_seq[0].reshape(1, X_test_seq.shape[1], X_test_seq.shape[2])  # Reshape as per model input
    # Get the baseline (e.g., use zeros as baseline)
    baseline = np.zeros_like(X_test_instance)
    # Compute the Integrated Gradients for the model
    feature_importance = integrated_gradients(model, X_test_instance, baseline=baseline)

    fig,ax = plt.subplots(1,1,figsize=(12,5))
    
    ax.bar(range(len(feature_importance)), feature_importance,color="#48A9A6")
    ax.set_xticks(range(len(feature_importance)), features_lstm, rotation=45)
    ax.set_xlabel("Feature Index")
    ax.set_ylabel("Importance (Integrated Gradients)")
    ax.set_title(f"Feature Importance using Integrated Gradients for {model_type}",loc='left')

# %%
def plot_performance_metrics(models_metrics,models_names):
    """
    Plots the performance of all models based on a set
    of metrics provided
    """
    # Create a DataFrame from the dictionaries
    metrics_df = pd.DataFrame(models_metrics, index=models_names)

    # Create a heatmap
    fig, ax = plt.subplots(1,1,figsize=(12,8))
    print('plotting')
    sns.heatmap(metrics_df, annot=True, cmap='coolwarm', fmt=".2f", cbar=True, linewidths=0.5)

    # Customize the plot
    ax.set_title('Model Evaluation Metrics - All Models',loc='left')
    ax.set_ylabel('Models')
    ax.set_xlabel('Metrics')

    # Show the plot
    fig.tight_layout()

# %%
def full_routine(lags_dict,input_data,load_saved_models=False,save_models=False,sequential=False,xgtune=False,
                trainyrs=10,valyrs=2,label='deliveries',model_ext='testing',plot_precip=False):
    """
    Performs the full analysis routine for set of inputs and produces all necessary
    figures to evaluate the models for those variables

    Parameters
    ----------
    lags_dict : which features to use and what lags they should have
    input_data : data with all possible variables to input
    load_saved_models : should already saved models be used (important for sequential models)
    save_models : should the models themselves be saved
    sequential : should the sequential models be run
    xgtune : should hyperparameter tuning for xgboost be done

    Returns 
    -------
    """

    # create training and testing splits for the data
    # Training and testing data for the deep learning models
    X_train_seq, X_val_seq, X_test_seq, y_train_seq, y_val_seq, y_test_seq, denorm_dict_seq, dates_dict_seq, feature_cols_seq = process_data(
        df, lookback_period=lookback_period, lag_dict=lags_dict, trainyrs=trainyrs, valyrs=valyrs,debug=1,target_column=label)

    # Training and testing data for the tree models
    X_train_xg, X_val_xg, X_test_xg, y_train_xg, y_val_xg, y_test_xg, denorm_dict_xg, dates_dict_xg, feature_cols_xg = process_data_for_xgboost(
        df,target_column=label, lag_dict=lags_dict, debug=0,trainyrs=trainyrs, valyrs=valyrs)

    #---- train the baseline models for comparison ----#

    # get the persistence baseline
    print('Training Persistence Model')
    persistence_preds, persistence_y_test, persistence_metrics = evaluate_persistence_model(y_train_xg, y_test_xg, denorm_dict_xg)

    # run the tree based models
    ## random forest
    print('Training Random Forest Model')
    rf_model = RandomForestRegressor(n_estimators=1500, max_depth=12, random_state=42)
    rf_model, rf_predictions, rf_y_test, rf_metrics = evaluate_rf_model(
    rf_model, X_train_xg, y_train_xg, X_val_xg, y_val_xg, X_test_xg, y_test_xg, denorm_dict_xg
    )
    print('Random Forest Complete')

    ## XGBoost
    print('Training XGBoost Model')
    xgb_model = XGBRegressor(n_estimators=1500,max_depth=12,min_child_weight=3,learning_rate=0.03,reg_alpha=0.07,objective='reg:pseudohubererror',huber_slope=1.5)
    xgb_model, xgb_predictions, xgb_y_test, xgb_metrics = train_evaluate_xgboost_model(
    xgb_model, X_train_xg, y_train_xg, X_val_xg, y_val_xg, X_test_xg, y_test_xg, denorm_dict_xg
    )
    print('XGBoost Complete')

    if sequential:
        # NOTE: need to add the option to load and save models here
        ## LSTM
        print('Training LSTM model')
        lstm_model = Sequential([
            LSTM(128, activation='tanh',kernel_regularizer=l2(0.07), return_sequences=True, input_shape=(lookback_period, X_train_seq.shape[2])),
            Dropout(0.6),
            LSTM(64, activation='tanh'),
            Dropout(0.6),
            Dense(1)
        ])
        lstm_model.compile(loss=Huber(delta=1.5), optimizer=Adam(), metrics=['mae'])
        # Evaluate LSTM MODEL
        lstm_model, lstm_predictions, lstm_y_test, lstm_metrics = train_evaluate_sequential(
            lstm_model, X_train_seq, y_train_seq, X_val_seq, y_val_seq, X_test_seq, y_test_seq, denorm_dict_seq)
        if save_models:
            lstm_model.save(f'/Users/laratobias-tarsh/Documents/SEAS_hydro/ml_models/lstm_model_test_{model_ext}.keras')
        print('LSTM Complete')

        ## GRU
        print('Training GRU model')
        gru_model = Sequential([
            GRU(128, activation='tanh',kernel_regularizer=l2(0.07), return_sequences=True, input_shape=(lookback_period, X_train_seq.shape[2])),
            Dropout(0.6),
            GRU(64, activation='tanh'),
            Dropout(0.6),
            Dense(1)
        ])
        gru_model.compile(loss=Huber(delta=1.5), optimizer=Adam(), metrics=['mean_absolute_error'])
        # EVALUATE GRU MODEL
        gru_model, gru_predictions, gru_y_test, gru_metrics = train_evaluate_sequential(
            gru_model, X_train_seq, y_train_seq, X_val_seq, y_val_seq, X_test_seq, y_test_seq, denorm_dict_seq
        )
        if save_models:
            gru_model.save(f'/Users/laratobias-tarsh/Documents/SEAS_hydro/ml_models/gru_model_test_{model_ext}.keras')
        print('GRU Complete')


    #---- Generate plots for each model ----#
    print('Plotting Results')
    #---- Plot performance metrics ---#
    if sequential:
        model_metrics = [lstm_metrics, gru_metrics, rf_metrics, xgb_metrics, persistence_metrics]
        model_names = ['LSTM', 'GRU', 'Random Forest', 'XGBoost', 'Persistence']
    else:
        model_metrics = [rf_metrics, xgb_metrics, persistence_metrics]
        model_names = ['Random Forest', 'XGBoost', 'Persistence']


    plot_performance_metrics(model_metrics,model_names)

    #--- Plot the flow predictions ---#
    # XGBoost
    plot_predictions(xgb_y_test,xgb_predictions,'XGBoost',color=IBM_PURPLE,dates=dates_dict_xg)
    # Random Forest
    plot_predictions(rf_y_test,rf_predictions,'Random Forest',color=IBM_BLUE,dates=dates_dict_xg)
    # Persistence
    plot_predictions(persistence_y_test,persistence_preds,'Persistence',color=IBM_YELLOW,dates=dates_dict_xg)
    

    if sequential:
        plot_predictions(lstm_y_test,lstm_predictions,'LSTM',color=IBM_PINK,dates=dates_dict_seq)
        plot_predictions(gru_y_test,gru_predictions,'GRU',color=IBM_ORANGE,dates=dates_dict_seq)

    print('Plotting Correlation')
    # shapley values for tree based models
    explainer_rf = shap.Explainer(rf_model,feature_names=feature_names_xg)
    shap_values_rf = explainer_rf(X_test_xg)
    # Summary plot with feature names
    #print('Shapley Values for Random Forest Model')
    #shap.summary_plot(shap_values_rf, X_test_xg, feature_names=feature_names_xg,max_display=20,show=False)
    
    
    explainer_xgb = shap.Explainer(xgb_model,feature_names=feature_names_xg)
    shap_values_xgb = explainer_xgb(X_test_xg)
    # Summary plot with feature names
    #print('Shapley Values for XGBoost Model')
    #shap.summary_plot(shap_values_xgb, X_test_xg, feature_names=feature_names_xg,max_display=20,show=False)
    print('Shapley Values for Random Forest Model')
    plt.figure()
    plt.subplot(1,1,1)
    shap.plots.beeswarm(
        shap_values_rf, max_display=20, show=False)

    print('Shapley Values for XGBoost Model')
    plt.figure()
    plt.subplot(1,1,1)
    shap.plots.beeswarm(
        shap_values_xgb, max_display=20, show=False)


    if sequential:
        plot_integrated_grads(X_test_seq,feature_names_seq,lstm_model,'LSTM')
        plot_integrated_grads(X_test_seq,feature_names_seq,gru_model,'GRU')

        
    

    #--- should we do hyperparameter tuning for XGBoost? ---#

    if xgtune:
        print('Hyperparameter tuning for XGBoost')
        param_distributions = {
        'n_estimators': [100, 500, 1000, 1500],
        'learning_rate': [0.005, 0.01, 0.03, 0.1],
        'max_depth': [6, 8, 10, 12],
        'min_child_weight': [1, 2, 3, 4],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'reg_alpha': [0.05, 0.1, 0.4, 0.6],
        'reg_lambda': [0.8, 1.0, 1.2, 1.5],
        'objective': ['reg:quantileerror','reg:pseudohubererror'],  # Quantile regression objective
        'huber_slope' : [0.75,1.0,1.25,1.5],
        'quantile_alpha': [0.95, 0.99, 0.995, 0.999],
        }

        # Initialize the XGBRegressor
        xgb_model = XGBRegressor()

        # Set up RandomizedSearchCV with the parameter grid
        random_search = RandomizedSearchCV(
            estimator=xgb_model,
            param_distributions=param_distributions,
            n_iter=100,  # Number of parameter settings sampled
            cv=5,
            verbose=False,
            n_jobs=-1,
            random_state=42
        )

        # Fit the model to the training data
        random_search.fit(X_train_xg, y_train_xg)

        # Get the best hyperparameters
        best_params = random_search.best_params_
        print(f"Best parameters found: {best_params}")

        # Train the final model with the best hyperparameters
        best_xgb_model = random_search.best_estimator_
        print('Training optimized XGBoost Model')
        best_xgb_model, best_xgb_predictions, best_xgb_y_test, best_xgb_metrics = train_evaluate_xgboost_model(
            xgb_model, X_train_xg, y_train_xg, X_val_xg, y_val_xg, X_test_xg, y_test_xg, denorm_dict_xg
        )

        print('Plotting results')
        explainer_xgb_best = shap.Explainer(best_xgb_model)
        shap_values_xgb_best = explainer_xgb_best(X_test_xg)
        # Summary plot with feature names
        print('Shapley Values for Best XGBoost Model')
        plot_predictions(xgb_y_test,best_xgb_predictions,'Tuned XGBoost',color=IBM_PURPLE,dates=dates_dict_xg)
        shap.summary_plot(shap_values_xgb_best, X_test_xg, feature_names=feature_names_xg,max_display=20)

        #---- Plot performance metrics ---#
        if sequential:
            model_metrics = [lstm_metrics, gru_metrics, rf_metrics, metrics_xgb, best_xgb_metrics, persistence_metrics]
            model_names = ['LSTM', 'GRU', 'Random Forest', 'XGBoost', 'XGBoost Tuned', 'Persistence']
        else:
            model_metrics = [rf_metrics, metrics_xgb, persistence_metrics]
            model_names = ['Random Forest', 'XGBoost', 'XGBoost Tuned', 'Persistence']

        plot_performance_metrics(model_metrics,model_names)

plt.show()

# %% [markdown]
# ## DATA PROCESSING

# %%
#### IMPORTING DATA FOR THE CONCHOS ####
# STREAMFLOW #
conchos_dis = clean_IBWC_csvs("/Users/laratobias-tarsh/Documents/SEAS_hydro/deliveries/IBWC_data/conchos_discharge.csv",
                              value_current="Average (m^3/d)",value_target="conchos_flow",start_date='2000-06-01',end_date='2019-12-31')

alv_dis = clean_IBWC_csvs("/Users/laratobias-tarsh/Documents/SEAS_hydro/deliveries/IBWC_data/arroyo_las_vacas_discharge.csv",
                              value_current="Average (m^3/d)",value_target="alv_flow",start_date='2000-06-01',end_date='2019-12-31')

escon_dis = clean_IBWC_csvs("/Users/laratobias-tarsh/Documents/SEAS_hydro/deliveries/IBWC_data/escondido_discharge.csv",
                              value_current="Average (m^3/d)",value_target="escon_flow",start_date='2000-06-01',end_date='2019-12-31')

salado_dis = clean_IBWC_csvs("/Users/laratobias-tarsh/Documents/SEAS_hydro/deliveries/IBWC_data/salado_discharge.csv",
                              value_current="Average (m^3/d)",value_target="salado_flow",start_date='2000-06-01',end_date='2019-12-31')

srod_dis = clean_IBWC_csvs("/Users/laratobias-tarsh/Documents/SEAS_hydro/deliveries/IBWC_data/san_rodrigo_discharge.csv",
                              value_current="Average (m^3/d)",value_target="srod_flow",start_date='2000-06-01',end_date='2019-12-31')

sdie_dis = clean_IBWC_csvs("/Users/laratobias-tarsh/Documents/SEAS_hydro/deliveries/IBWC_data/san_diego_discharge.csv",
                              value_current="Average (m^3/d)",value_target="sdie_flow",start_date='2000-06-01',end_date='2019-12-31')

# RESERVOIR STORAGE #
laboq_stor = clean_IBWC_csvs("/Users/laratobias-tarsh/Documents/SEAS_hydro/storage_csvs/la_boquilla_storage.csv", datecol="Timestamp (UTC-06:00)",
                              value_current="Value (TCM)",value_target="lb_storage",start_date='2000-06-01',end_date='2019-12-31')

ami_stor = clean_IBWC_csvs("/Users/laratobias-tarsh/Documents/SEAS_hydro/storage_csvs/amistad_storage.csv", datecol="Timestamp (UTC-06:00)",
                              value_current="Value (TCM)",value_target="ami_storage",start_date='2000-06-01',end_date='2019-12-31')

falc_stor = clean_IBWC_csvs("/Users/laratobias-tarsh/Documents/SEAS_hydro/storage_csvs/falcon_storage.csv", datecol="Timestamp (UTC-06:00)",
                              value_current="Value (TCM)",value_target="falc_storage",start_date='2000-06-01',end_date='2019-12-31')

deliveries = clean_IBWC_csvs("/Users/laratobias-tarsh/Documents/SEAS_hydro/deliveries/IBWC_data/third_deliveries.csv", datecol="Start of Interval (UTC-06:00)",
                              value_current="Average (m^3/d)",value_target="deliveries",start_date='2000-06-01',end_date='2019-12-31',skiphead=0,skipfoot=0)
# Conchos daymet
# Basin precip
rgb_precip = pd.read_csv("/Users/laratobias-tarsh/Documents/SEAS_hydro/mexico_basin_totals.csv")
rgb_precip_total = rgb_precip.drop(['non_tc','idx'],axis='columns')
rgb_precip_total['date'] = pd.to_datetime(rgb_precip_total['date'])
# Out:
# No columns to drop, continuing...
# No columns to drop, continuing...
# No columns to drop, continuing...

# %% [markdown]
# #### Prepare the data for machine learning

# %%
##### CONCAT DATA #####
merged_df = pd.merge(conchos_dis, rgb_precip_total, on='date')
merged_df2 = pd.merge(merged_df, laboq_stor, on='date')
merged_df3 = pd.merge(merged_df2, ami_stor, on='date')
merged_df4 = pd.merge(merged_df3, alv_dis, on='date')
merged_df5 = pd.merge(merged_df4, escon_dis, on='date')
merged_df6 = pd.merge(merged_df5, salado_dis, on='date')
merged_df7 = pd.merge(merged_df6, srod_dis, on='date')
merged_df8 = pd.merge(merged_df7, sdie_dis, on='date')
merged_df9 = pd.merge(merged_df8, deliveries, on='date')
ml_data = pd.merge(merged_df9, falc_stor, on='date')

ml_data['conchos_flow'] = ml_data.conchos_flow * 0.000001
ml_data['alv_flow'] = ml_data.alv_flow * 0.000001
ml_data['escon_flow'] = ml_data.escon_flow * 0.000001
ml_data['salado_flow'] = ml_data.salado_flow * 0.000001
ml_data['sdie_flow'] = ml_data.sdie_flow * 0.000001
ml_data['srod_flow'] = ml_data.srod_flow * 0.000001
ml_data['deliveries'] = ml_data.deliveries * 0.000001



ml_data['ami_storage'] = ml_data.ami_storage * 0.001
ml_data['lb_storage'] = ml_data.lb_storage * 0.001
ml_data['falc_storage'] = ml_data.falc_storage * 0.001

ml_data['ami_conservation'] = 3980096 * 0.001
ml_data['ami_flood'] = 6055720 * 0.001
ml_data['ami_dead'] = 40358 * 0.001

ml_data['falc_conservation'] = 3288726 * 0.001
ml_data['falc_flood'] = 3923322 * 0.001
ml_data['falc_dead'] = 12 * 0.001

ml_data['lb_conservation'] = 2893571 * 0.001
ml_data['lb_flood'] = 3208267 * 0.001
ml_data['lb_dead'] = 106087 * 0.001

## now calculating some monthly means
# List of flow columns (make sure to adjust this list based on your actual columns)
flow_columns = ['conchos_flow', 'alv_flow', 'escon_flow', 'salado_flow', 'srod_flow','sdie_flow']  # Add more flow columns if needed

# Calculate the 30-day rolling average for each flow column
for column in flow_columns:
    ml_data[f'{column}_30d_avg'] = ml_data[column].rolling(window=30, min_periods=1).mean()
    # engineer the NDI value


#ml_data['tc'] = (ml_data['tc'] != 0).astype(int)

# %%
lags_dict = {
    "conchos_flow" : [1,7],
    "alv_flow" : [1,7],
    "salado_flow" : [1,7],
    "escon_flow" : [1,7],
    "sdie_flow" : [1,7],
    "srod_flow" : [1,7],
    "lb_storage" :[1,7],
    "ami_storage" :[1,7],
    "falc_storage" :[1,7],
    "precipitation" : 7,
    "ami_conservation" : 1,
    "ami_flood" : 1,
    "falc_conservation" : 1,
    "falc_flood" : 1,
    "lb_conservation" : 1,
    "lb_flood" : 1,
    "tc": [1,3,7]
}


lags_dict = {
    "conchos_flow_30d_avg" : 1,
    "alv_flow_30d_avg" : 1,
    "salado_flow_30d_avg" : 1,
    "escon_flow_30d_avg" : 1,
    "sdie_flow_30d_avg" : 1,
    "srod_flow_30d_avg" : 1,
    "lb_storage" : 1,
    "ami_storage" : 1,
    "falc_storage" : 1,
    "precipitation" : 7,
    "ami_conservation" : 1,
    "ami_flood" : 1,
    "falc_conservation" : 1,
    "falc_flood" : 1,
    "lb_conservation" : 1,
    "lb_flood" : 1,
    "tc": [1,3,7]
}

### Load Data
df = ml_data
lookback_period = 365
df
# Out:
#            date  conchos_flow  precipitation   tc  lb_storage  ami_storage  \
# 0    2000-06-01      1.693451    8204.110000  0.0      892.46     1395.700
# 1    2000-06-02      1.140487   12233.294000  0.0      893.15     1398.100
# 2    2000-06-03      1.123207   12556.989000  0.0      891.10     1398.100
# 3    2000-06-04      2.574737    8336.385000  0.0      889.05     1397.500
# 4    2000-06-05      2.168654    7789.029300  0.0      886.32     1395.100
# ...         ...           ...            ...  ...         ...          ...
# 7148 2019-12-27      1.235528      31.009998  0.0     2004.75     2065.245
# 7149 2019-12-28      1.200968     752.589970  0.0     2004.75     2068.479
# 7150 2019-12-29      1.270088     235.214980  0.0     2004.75     2070.099
# 7151 2019-12-30      1.270088       4.250000  0.0     2003.40     2070.904
# 7152 2019-12-31      1.252808     504.484950  0.0     2003.40     2070.904
#
#       alv_flow  escon_flow  salado_flow  srod_flow  ...  falc_dead  \
# 0     0.008640    0.014688     0.237602   0.039744  ...      0.012
# 1     0.010368    0.016416     0.089857   0.039744  ...      0.012
# 2     0.009504    0.017280     0.032832   0.032832  ...      0.012
# 3     0.009504    0.017280     0.016416   0.019008  ...      0.012
# 4     0.009504    0.049248     0.011232   0.013824  ...      0.012
# ...        ...         ...          ...        ...  ...        ...
# 7148  0.022464    0.034560     0.018144   0.000000  ...      0.012
# 7149  0.022464    0.037152     0.021600   0.000000  ...      0.012
# 7150  0.021600    0.037152     0.019008   0.000000  ...      0.012
# 7151  0.020736    0.036288     0.013824   0.000000  ...      0.012
# 7152  0.020736    0.038880     0.012960   0.000000  ...      0.012
#
#       lb_conservation  lb_flood  lb_dead  conchos_flow_30d_avg  \
# 0            2893.571  3208.267  106.087              1.693451
# 1            2893.571  3208.267  106.087              1.416969
# 2            2893.571  3208.267  106.087              1.319049
# 3            2893.571  3208.267  106.087              1.632971
# 4            2893.571  3208.267  106.087              1.740107
# ...               ...       ...      ...                   ...
# 7148         2893.571  3208.267  106.087              1.268072
# 7149         2893.571  3208.267  106.087              1.264616
# 7150         2893.571  3208.267  106.087              1.263176
# 7151         2893.571  3208.267  106.087              1.262312
# 7152         2893.571  3208.267  106.087              1.261448
#
#       alv_flow_30d_avg  escon_flow_30d_avg  salado_flow_30d_avg  \
# 0             0.008640            0.014688             0.237602
# 1             0.009504            0.015552             0.163729
# 2             0.009504            0.016128             0.120097
# 3             0.009504            0.016416             0.094177
# 4             0.009504            0.022983             0.077588
# ...                ...                 ...                  ...
# 7148          0.019786            0.032055             0.008352
# 7149          0.019901            0.032458             0.008554
# 7150          0.019987            0.032861             0.008755
# 7151          0.020045            0.033149             0.008870
# 7152          0.020103            0.033610             0.009014
#
#       srod_flow_30d_avg  sdie_flow_30d_avg
# 0              0.039744           0.020736
# 1              0.039744           0.022032
# 2              0.037440           0.021600
# 3              0.032832           0.021384
# 4              0.029031           0.021946
# ...                 ...                ...
# 7148           0.000000           0.174155
# 7149           0.000000           0.176574
# 7150           0.000000           0.178043
# 7151           0.000000           0.178763
# 7152           0.000000           0.179339
#
# [7153 rows x 28 columns]

# %% [markdown]
# ## FEATURE SELECTION
# 1. Look at correlation between features (including engineered features)
# 2. Look at cross-correlation function between rainfall-runoff and TC rainfall-runoff
# 3. Explain engineered features

# %%
# Select the columns of interest

variables_of_interest = ['conchos_flow','escon_flow','salado_flow','srod_flow','alv_flow','sdie_flow',
                         'conchos_flow_30d_avg','escon_flow_30d_avg','salado_flow_30d_avg','srod_flow_30d_avg','alv_flow_30d_avg','sdie_flow_30d_avg',
                         'ami_storage','falc_storage','lb_storage','precipitation','tc','deliveries']

# Calculate the pairwise correlation matrix
correlation_matrix = df[variables_of_interest].corr()
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(20, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='magma_r', fmt='.2f', 
            cbar_kws={'label': 'Correlation Coefficient'}, square=True,mask=mask)

plt.title('Feature Cross-Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Feature Cross-Correlation Matrix')

# %%
full_routine(lags_dict,df)
# Out:
# Training Persistence Model
# Training Random Forest Model
# Random Forest Complete
# Training XGBoost Model
# XGBoost Complete
# Plotting Results
# plotting
# Plotting Correlation
# Shapley Values for Random Forest Model
# Shapley Values for XGBoost Model

# %% [markdown]
# ### BUILD MODELS

# %%
# Training and testing data for the deep learning models
X_train_seq, X_val_seq, X_test_seq, y_train_seq, y_val_seq, y_test_seq, denorm_dict_seq, dates_dict_seq, feature_cols_seq = process_data(
    df, lookback_period=lookback_period, lag_dict=lags_dict, trainyrs=9, valyrs=2,debug=1,target_column='deliveries')

# Training and testing data for the tree models
X_train_xg, X_val_xg, X_test_xg, y_train_xg, y_val_xg, y_test_xg, denorm_dict_xg, dates_dict_xg, feature_names_xg = process_data_for_xgboost(
    df,target_column='deliveries', lag_dict=lags_dict, debug=0,trainyrs=10, valyrs=2)

# %%
def quantile_loss(q, y_true, y_pred):
    # Calculate the error
    error = y_true - y_pred
    # Compute quantile loss for the given quantile q
    loss = K.mean(K.maximum(q * error, (q - 1) * error), axis=-1)
    return loss

# %%
### Define Models
### LSTM MODEL ###
lstm_model = Sequential([
    LSTM(128, activation='tanh',kernel_regularizer=l2(0.07), return_sequences=True, input_shape=(lookback_period, X_train_seq.shape[2])),
    Dropout(0.6),
    LSTM(64, activation='tanh'),
    Dropout(0.6),
    Dense(1)
])
lstm_model.compile(loss=Huber(delta=1.5), optimizer=Adam(), metrics=['mae'])

# %%
### GRU MODEL ###
gru_model = Sequential([
    GRU(128, activation='tanh',kernel_regularizer=l2(0.07), return_sequences=True, input_shape=(lookback_period, X_train_seq.shape[2])),
    Dropout(0.6),
    GRU(64, activation='tanh'),
    Dropout(0.6),
    Dense(1)
])
gru_model.compile(loss=Huber(delta=1.5), optimizer=Adam(), metrics=['mean_absolute_error'])

# %%
param_distributions = {
    'n_estimators': [100, 500, 1000, 1500],
    'learning_rate': [0.005, 0.01, 0.03, 0.1],
    'max_depth': [6, 8, 10, 12],
    'min_child_weight': [1, 2, 3, 4],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'reg_alpha': [0.1, 0.4, 0.6, 1.0],
    'reg_lambda': [0.8, 1.0, 1.2, 1.5],
    'objective': ['reg:quantileerror'],  # Quantile regression objective
    'quantile_alpha': [0.95, 0.99, 0.995, 0.999],
}

# Initialize the XGBRegressor
xgb_model = XGBRegressor()

# Set up RandomizedSearchCV with the parameter grid
random_search = RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=param_distributions,
    n_iter=100,  # Number of parameter settings sampled
    cv=5,
    verbose=False,
    n_jobs=-1,
    random_state=42
)

# Fit the model to the training data
random_search.fit(X_train_xg, y_train_xg)

# Get the best hyperparameters
best_params = random_search.best_params_
print(f"Best parameters found: {best_params}")

# Train the final model with the best hyperparameters
best_xgb_model = random_search.best_estimator_
# Out:
# Best parameters found: {'subsample': 0.8, 'reg_lambda': 1.0, 'reg_alpha': 0.4, 'quantile_alpha': 0.95, 'objective': 'reg:quantileerror', 'n_estimators': 1500, 'min_child_weight': 3, 'max_depth': 12, 'learning_rate': 0.03, 'colsample_bytree': 0.6}

# %%
rf_model = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42)

# %% [markdown]
# ### EVALUTE MODELS

# %%
# Evaluate the persistence model
persistence_preds, persistence_y_test, persistence_metrics = evaluate_persistence_model(y_train_xg, y_test_xg, denorm_dict_xg)

# %%
# Evaluate LSTM MODEL
lstm_history, lstm_preds, y_test_denorm_lstm, lstm_metrics = train_evaluate_sequential(
    lstm_model, X_train_seq, y_train_seq, X_val_seq, y_val_seq, X_test_seq, y_test_seq, denorm_dict_seq)
#lstm_model.save('lstm_model.keras')
# Out:
# Epoch 1/20
# 92/92 [==============================] - 30s 310ms/step - loss: 1.3385 - mae: 0.3153 - val_loss: 0.2165 - val_mae: 0.1855
# Epoch 2/20
# 92/92 [==============================] - 29s 314ms/step - loss: 0.2267 - mae: 0.2461 - val_loss: 0.0702 - val_mae: 0.1913
# Epoch 3/20
# 92/92 [==============================] - 29s 318ms/step - loss: 0.1757 - mae: 0.2401 - val_loss: 0.0579 - val_mae: 0.1549
# Epoch 4/20
# 92/92 [==============================] - 28s 307ms/step - loss: 0.1709 - mae: 0.2406 - val_loss: 0.0454 - val_mae: 0.1219
# Epoch 5/20
# 92/92 [==============================] - 29s 315ms/step - loss: 0.1579 - mae: 0.2228 - val_loss: 0.0538 - val_mae: 0.2002
# Epoch 6/20
# 92/92 [==============================] - 28s 306ms/step - loss: 0.1444 - mae: 0.2141 - val_loss: 0.0482 - val_mae: 0.1650
# Epoch 7/20
# 92/92 [==============================] - 27s 295ms/step - loss: 0.1431 - mae: 0.2153 - val_loss: 0.0456 - val_mae: 0.1355
# Epoch 8/20
# 92/92 [==============================] - 27s 292ms/step - loss: 0.1295 - mae: 0.2071 - val_loss: 0.0451 - val_mae: 0.1492
# Epoch 9/20
# 92/92 [==============================] - 28s 310ms/step - loss: 0.1471 - mae: 0.2162 - val_loss: 0.0503 - val_mae: 0.1817
# Epoch 10/20
# 92/92 [==============================] - 28s 303ms/step - loss: 0.1429 - mae: 0.2161 - val_loss: 0.0456 - val_mae: 0.1162
# Epoch 11/20
# 92/92 [==============================] - 28s 302ms/step - loss: 0.1271 - mae: 0.2049 - val_loss: 0.0444 - val_mae: 0.1308
# Epoch 12/20
# 92/92 [==============================] - 27s 297ms/step - loss: 0.1406 - mae: 0.2153 - val_loss: 0.0473 - val_mae: 0.1033
# Epoch 13/20
# 92/92 [==============================] - 27s 293ms/step - loss: 0.1278 - mae: 0.2021 - val_loss: 0.0482 - val_mae: 0.1789
# Epoch 14/20
# 92/92 [==============================] - 28s 300ms/step - loss: 0.1388 - mae: 0.2115 - val_loss: 0.0434 - val_mae: 0.1496
# Epoch 15/20
# 92/92 [==============================] - 28s 305ms/step - loss: 0.1257 - mae: 0.1969 - val_loss: 0.0556 - val_mae: 0.2035
# Epoch 16/20
# 92/92 [==============================] - 28s 309ms/step - loss: 0.1333 - mae: 0.2015 - val_loss: 0.0433 - val_mae: 0.1484
# Epoch 17/20
# 92/92 [==============================] - 29s 312ms/step - loss: 0.1273 - mae: 0.1971 - val_loss: 0.0453 - val_mae: 0.1619
# Epoch 18/20
# 92/92 [==============================] - 30s 323ms/step - loss: 0.1256 - mae: 0.1977 - val_loss: 0.0758 - val_mae: 0.1758
# Epoch 19/20
# 92/92 [==============================] - 29s 313ms/step - loss: 0.1143 - mae: 0.1872 - val_loss: 0.0441 - val_mae: 0.1190
# Epoch 20/20
# 92/92 [==============================] - 28s 304ms/step - loss: 0.1216 - mae: 0.1917 - val_loss: 0.0425 - val_mae: 0.1147
# 110/110 [==============================] - 10s 89ms/step

# %%
# EVALUATE GRU MODEL
gru_history, gru_preds, y_test_denorm_gru, gru_metrics = train_evaluate_sequential(
    gru_model, X_train_seq, y_train_seq, X_val_seq, y_val_seq, X_test_seq, y_test_seq, denorm_dict_seq
)

#gru_model.save('gru_model.keras')
# Out:
# Epoch 1/20
# 92/92 [==============================] - 25s 254ms/step - loss: 0.2184 - mean_absolute_error: 0.3546 - val_loss: 0.0331 - val_mean_absolute_error: 0.1281
# Epoch 2/20
# 92/92 [==============================] - 23s 246ms/step - loss: 0.1609 - mean_absolute_error: 0.2885 - val_loss: 0.0244 - val_mean_absolute_error: 0.1260
# Epoch 3/20
# 92/92 [==============================] - 23s 246ms/step - loss: 0.1340 - mean_absolute_error: 0.2576 - val_loss: 0.0198 - val_mean_absolute_error: 0.1187
# Epoch 4/20
# 92/92 [==============================] - 23s 247ms/step - loss: 0.1223 - mean_absolute_error: 0.2448 - val_loss: 0.0203 - val_mean_absolute_error: 0.1204
# Epoch 5/20
# 92/92 [==============================] - 23s 250ms/step - loss: 0.1067 - mean_absolute_error: 0.2217 - val_loss: 0.0191 - val_mean_absolute_error: 0.1085
# Epoch 6/20
# 92/92 [==============================] - 23s 246ms/step - loss: 0.1056 - mean_absolute_error: 0.2201 - val_loss: 0.0204 - val_mean_absolute_error: 0.1285
# Epoch 7/20
# 92/92 [==============================] - 22s 244ms/step - loss: 0.0977 - mean_absolute_error: 0.2128 - val_loss: 0.0211 - val_mean_absolute_error: 0.1437
# Epoch 8/20
# 92/92 [==============================] - 23s 249ms/step - loss: 0.0973 - mean_absolute_error: 0.2125 - val_loss: 0.0189 - val_mean_absolute_error: 0.1008
# Epoch 9/20
# 92/92 [==============================] - 22s 243ms/step - loss: 0.0982 - mean_absolute_error: 0.2072 - val_loss: 0.0230 - val_mean_absolute_error: 0.1151
# Epoch 10/20
# 92/92 [==============================] - 23s 249ms/step - loss: 0.1006 - mean_absolute_error: 0.2097 - val_loss: 0.0192 - val_mean_absolute_error: 0.1094
# Epoch 11/20
# 92/92 [==============================] - 24s 260ms/step - loss: 0.0970 - mean_absolute_error: 0.1994 - val_loss: 0.0196 - val_mean_absolute_error: 0.1053
# Epoch 12/20
# 92/92 [==============================] - 24s 260ms/step - loss: 0.0861 - mean_absolute_error: 0.1917 - val_loss: 0.0197 - val_mean_absolute_error: 0.1034
# Epoch 13/20
# 92/92 [==============================] - 24s 257ms/step - loss: 0.0849 - mean_absolute_error: 0.1900 - val_loss: 0.0205 - val_mean_absolute_error: 0.1122
# Epoch 14/20
# 92/92 [==============================] - 24s 260ms/step - loss: 0.0915 - mean_absolute_error: 0.1995 - val_loss: 0.0179 - val_mean_absolute_error: 0.1039
# Epoch 15/20
# 92/92 [==============================] - 23s 255ms/step - loss: 0.0817 - mean_absolute_error: 0.1839 - val_loss: 0.0216 - val_mean_absolute_error: 0.1364
# Epoch 16/20
# 92/92 [==============================] - 24s 264ms/step - loss: 0.0805 - mean_absolute_error: 0.1814 - val_loss: 0.0170 - val_mean_absolute_error: 0.0972
# Epoch 17/20
# 92/92 [==============================] - 23s 253ms/step - loss: 0.0848 - mean_absolute_error: 0.1857 - val_loss: 0.0216 - val_mean_absolute_error: 0.1359
# Epoch 18/20
# 92/92 [==============================] - 23s 255ms/step - loss: 0.0864 - mean_absolute_error: 0.1850 - val_loss: 0.0204 - val_mean_absolute_error: 0.1174
# Epoch 19/20
# 92/92 [==============================] - 24s 259ms/step - loss: 0.0880 - mean_absolute_error: 0.1896 - val_loss: 0.0217 - val_mean_absolute_error: 0.1147
# Epoch 20/20
# 92/92 [==============================] - 25s 269ms/step - loss: 0.0907 - mean_absolute_error: 0.1939 - val_loss: 0.0195 - val_mean_absolute_error: 0.1172
# 110/110 [==============================] - 8s 68ms/step

# %%
# EVALUATE RANDOM FOREST
rf_model, rf_predictions, rf_y_test, rf_metrics = evaluate_rf_model(
    rf_model, X_train_xg, y_train_xg, X_val_xg, y_val_xg, X_test_xg, y_test_xg, denorm_dict_xg
)
# Out:
# /opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/numpy/lib/function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %%
# EVALUATE XGBOOST
xgb_model, best_xgb_preds, denorm_y_test_xg, metrics_xgb = train_evaluate_xgboost_model(
    best_xgb_model, X_train_xg, y_train_xg, X_val_xg, y_val_xg, X_test_xg, y_test_xg, denorm_dict_xg
)
# Out:
# /opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/numpy/lib/function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %% [markdown]
# ### RESULTS

# %%
### LSTM
plot_integrated_grads(X_test_seq,features_lstm,lstm_model,'LSTM')
plot_predictions(y_test_denorm,lstm_preds,'LSTM',color=IBM_ORANGE)

# %%
### GRU
plot_integrated_grads(X_test_seq,features_lstm,gru_model,'GRU')
plot_predictions(y_test_denorm_gru,gru_preds,'GRU',color=IBM_BLUE)

# %%
### XGBOOST
explainer = shap.Explainer(best_xgb_model)
shap_values = explainer(X_test_xg)

# Summary plot with feature names
shap.summary_plot(shap_values, X_test_xg, feature_names=feature_names_xg)

plot_predictions(denorm_y_test_xg,best_xgb_preds,'XGBoost',color=IBM_PURPLE,dates=dates_dict_xg)

# %%
### RANDOM FOREST
explainer = shap.Explainer(rf_model)
shap_values = explainer(X_test_xg)

# Summary plot with feature names
shap.summary_plot(shap_values, X_test_xg, feature_names=feature_names_xg)

plot_predictions(rf_y_test,rf_predictions,'Random Forest',color=IBM_YELLOW,dates=dates_dict_xg)

# %%
model_metrics = [lstm_metrics, gru_metrics, rf_metrics, metrics_xgb, persistence_metrics]

# Define model names
model_names = ['LSTM', 'GRU', 'RF', 'XGB', 'Persistence']

# Create a DataFrame from the dictionaries
metrics_df = pd.DataFrame(model_metrics, index=model_names)

# Create a heatmap
#plt.figure(figsize=(10, 6))
fig, ax = plt.subplots(1,1,figsize=(12,8))
sns.heatmap(metrics_df, annot=True, cmap='coolwarm', fmt=".2f", cbar=True, linewidths=0.5)

# Customize the plot
ax.set_title('Model Evaluation Metrics - All Models',loc='left')
ax.set_ylabel('Models')
ax.set_xlabel('Metrics')

# Show the plot
fig.tight_layout()

# %% [markdown]
# ### EXTRA

# %%
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBRegressor

# Define the parameter grid to search, including the `alpha` for quantile regression
param_distributions = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.01, 0.03, 0.1],
    'max_depth': [4, 6, 8],
    'min_child_weight': [1, 2, 4],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'reg_alpha': [0, 0.4, 1.0],
    'reg_lambda': [0.8, 1.0, 1.2],
    'objective': ['reg:quantileerror'],  # Quantile regression objective
    'quantile_alpha': [0.7,0.9,0.95,0.99]  # Quantile parameter (0.9 for 90th percentile, change as needed)
}

# Initialize the XGBRegressor
xgb_model = XGBRegressor()

# Set up RandomizedSearchCV with the parameter grid
random_search = RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=param_distributions,
    n_iter=100,  # Number of parameter settings sampled
    cv=3,
    verbose=1,
    n_jobs=-1,
    random_state=42
)

# Fit the model to the training data
random_search.fit(X_train_xg, y_train_xg)

# Get the best hyperparameters
best_params = random_search.best_params_
print(f"Best parameters found: {best_params}")

# Train the final model with the best hyperparameters
best_xgb_model = random_search.best_estimator_

# Evaluate the final model (assuming train_evaluate_xgboost_model is defined)
xgb_model, best_xgb_preds, denorm_y_test_xg, metrics_xgb = train_evaluate_xgboost_model(
    best_xgb_model, X_train_xg, y_train_xg, X_val_xg, y_val_xg, X_test_xg, y_test_xg, denorm_dict_xg
)

# Print the metrics
for metric, value in metrics_xgb.items():
    print(f"{metric}: {value}")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best parameters found: {'subsample': 1.0, 'reg_lambda': 1.2, 'reg_alpha': 1.0, 'quantile_alpha': 0.9, 'objective': 'reg:quantileerror', 'n_estimators': 1000, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.01, 'colsample_bytree': 1.0}
# [0]	validation_0-quantile:0.07389
# [1]	validation_0-quantile:0.06954
# [2]	validation_0-quantile:0.06338
# [3]	validation_0-quantile:0.05785
# [4]	validation_0-quantile:0.05362
# [5]	validation_0-quantile:0.04936
# [6]	validation_0-quantile:0.04525
# [7]	validation_0-quantile:0.04013
# [8]	validation_0-quantile:0.03585
# [9]	validation_0-quantile:0.03525
# [10]	validation_0-quantile:0.03483
# [11]	validation_0-quantile:0.03470
# [12]	validation_0-quantile:0.03457
# [13]	validation_0-quantile:0.03453
# [14]	validation_0-quantile:0.03439
# [15]	validation_0-quantile:0.03428
# [16]	validation_0-quantile:0.03410
# [17]	validation_0-quantile:0.03395
# [18]	validation_0-quantile:0.03383
# [19]	validation_0-quantile:0.03364
# [20]	validation_0-quantile:0.03353
# [21]	validation_0-quantile:0.03332
# [22]	validation_0-quantile:0.03316
# [23]	validation_0-quantile:0.03304
# [24]	validation_0-quantile:0.03291
# [25]	validation_0-quantile:0.03281
# [26]	validation_0-quantile:0.03265
# [27]	validation_0-quantile:0.03252
# [28]	validation_0-quantile:0.03235
# [29]	validation_0-quantile:0.03221
# [30]	validation_0-quantile:0.03219
# [31]	validation_0-quantile:0.03225
# [32]	validation_0-quantile:0.03213
# [33]	validation_0-quantile:0.03196
# [34]	validation_0-quantile:0.03180
# [35]	validation_0-quantile:0.03169
# [36]	validation_0-quantile:0.03148
# [37]	validation_0-quantile:0.03132
# [38]	validation_0-quantile:0.03114
# [39]	validation_0-quantile:0.03108
# [40]	validation_0-quantile:0.03098
# [41]	validation_0-quantile:0.03089
# [42]	validation_0-quantile:0.03082
# [43]	validation_0-quantile:0.03078
# [44]	validation_0-quantile:0.03071
# [45]	validation_0-quantile:0.03066
# [46]	validation_0-quantile:0.03078
# [47]	validation_0-quantile:0.03073
# [48]	validation_0-quantile:0.03071
# [49]	validation_0-quantile:0.03062
# [50]	validation_0-quantile:0.03046
# [51]	validation_0-quantile:0.03041
# [52]	validation_0-quantile:0.03023
# [53]	validation_0-quantile:0.03005
# [54]	validation_0-quantile:0.02993
# [55]	validation_0-quantile:0.02981
# [56]	validation_0-quantile:0.02972
# [57]	validation_0-quantile:0.02968
# [58]	validation_0-quantile:0.02962
# [59]	validation_0-quantile:0.02956
# [60]	validation_0-quantile:0.02947
# [61]	validation_0-quantile:0.02945
# [62]	validation_0-quantile:0.02939
# [63]	validation_0-quantile:0.02934
# [64]	validation_0-quantile:0.02923
# [65]	validation_0-quantile:0.02917
# [66]	validation_0-quantile:0.02905
# [67]	validation_0-quantile:0.02896
# [68]	validation_0-quantile:0.02884
# [69]	validation_0-quantile:0.02874
# [70]	validation_0-quantile:0.02867
# [71]	validation_0-quantile:0.02860
# [72]	validation_0-quantile:0.02850
# [73]	validation_0-quantile:0.02845
# [74]	validation_0-quantile:0.02844
# [75]	validation_0-quantile:0.02846
# [76]	validation_0-quantile:0.02841
# [77]	validation_0-quantile:0.02837
# [78]	validation_0-quantile:0.02831
# [79]	validation_0-quantile:0.02833
# [80]	validation_0-quantile:0.02829
# [81]	validation_0-quantile:0.02826
# [82]	validation_0-quantile:0.02822
# [83]	validation_0-quantile:0.02813
# [84]	validation_0-quantile:0.02808
# [85]	validation_0-quantile:0.02808
# [86]	validation_0-quantile:0.02795
# [87]	validation_0-quantile:0.02790
# [88]	validation_0-quantile:0.02784
# [89]	validation_0-quantile:0.02781
# [90]	validation_0-quantile:0.02770
# [91]	validation_0-quantile:0.02768
# [92]	validation_0-quantile:0.02764
# [93]	validation_0-quantile:0.02759
# [94]	validation_0-quantile:0.02754
# [95]	validation_0-quantile:0.02747
# [96]	validation_0-quantile:0.02738
# [97]	validation_0-quantile:0.02733
# [98]	validation_0-quantile:0.02729
# [99]	validation_0-quantile:0.02729
# [100]	validation_0-quantile:0.02720
# [101]	validation_0-quantile:0.02712
# [102]	validation_0-quantile:0.02703
# [103]	validation_0-quantile:0.02697
# [104]	validation_0-quantile:0.02689
# [105]	validation_0-quantile:0.02680
# [106]	validation_0-quantile:0.02671
# [107]	validation_0-quantile:0.02670
# [108]	validation_0-quantile:0.02673
# [109]	validation_0-quantile:0.02668
# [110]	validation_0-quantile:0.02677
# [111]	validation_0-quantile:0.02673
# [112]	validation_0-quantile:0.02672
# [113]	validation_0-quantile:0.02668
# [114]	validation_0-quantile:0.02659
# [115]	validation_0-quantile:0.02657
# [116]	validation_0-quantile:0.02653
# [117]	validation_0-quantile:0.02646
# [118]	validation_0-quantile:0.02644
# [119]	validation_0-quantile:0.02639
# [120]	validation_0-quantile:0.02639
# [121]	validation_0-quantile:0.02648
# [122]	validation_0-quantile:0.02647
# [123]	validation_0-quantile:0.02643
# [124]	validation_0-quantile:0.02643
# [125]	validation_0-quantile:0.02643
# [126]	validation_0-quantile:0.02643
# [127]	validation_0-quantile:0.02642
# [128]	validation_0-quantile:0.02638
# [129]	validation_0-quantile:0.02635
# [130]	validation_0-quantile:0.02632
# [131]	validation_0-quantile:0.02632
# [132]	validation_0-quantile:0.02629
# [133]	validation_0-quantile:0.02625
# [134]	validation_0-quantile:0.02619
# [135]	validation_0-quantile:0.02615
# [136]	validation_0-quantile:0.02613
# [137]	validation_0-quantile:0.02609
# [138]	validation_0-quantile:0.02604
# [139]	validation_0-quantile:0.02603
# [140]	validation_0-quantile:0.02600
# [141]	validation_0-quantile:0.02599
# [142]	validation_0-quantile:0.02596
# [143]	validation_0-quantile:0.02593
# [144]	validation_0-quantile:0.02590
# [145]	validation_0-quantile:0.02586
# [146]	validation_0-quantile:0.02580
# [147]	validation_0-quantile:0.02581
# [148]	validation_0-quantile:0.02581
# [149]	validation_0-quantile:0.02578
# [150]	validation_0-quantile:0.02577
# [151]	validation_0-quantile:0.02577
# [152]	validation_0-quantile:0.02574
# [153]	validation_0-quantile:0.02571
# [154]	validation_0-quantile:0.02568
# [155]	validation_0-quantile:0.02565
# [156]	validation_0-quantile:0.02561
# [157]	validation_0-quantile:0.02562
# [158]	validation_0-quantile:0.02559
# [159]	validation_0-quantile:0.02561
# [160]	validation_0-quantile:0.02558
# [161]	validation_0-quantile:0.02555
# [162]	validation_0-quantile:0.02553
# [163]	validation_0-quantile:0.02555
# [164]	validation_0-quantile:0.02553
# [165]	validation_0-quantile:0.02551
# [166]	validation_0-quantile:0.02549
# [167]	validation_0-quantile:0.02546
# [168]	validation_0-quantile:0.02543
# [169]	validation_0-quantile:0.02541
# [170]	validation_0-quantile:0.02539
# [171]	validation_0-quantile:0.02535
# [172]	validation_0-quantile:0.02534
# [173]	validation_0-quantile:0.02532
# [174]	validation_0-quantile:0.02531
# [175]	validation_0-quantile:0.02527
# [176]	validation_0-quantile:0.02525
# [177]	validation_0-quantile:0.02522
# [178]	validation_0-quantile:0.02518
# [179]	validation_0-quantile:0.02517
# [180]	validation_0-quantile:0.02514
# [181]	validation_0-quantile:0.02511
# [182]	validation_0-quantile:0.02509
# [183]	validation_0-quantile:0.02507
# [184]	validation_0-quantile:0.02503
# [185]	validation_0-quantile:0.02500
# [186]	validation_0-quantile:0.02499
# [187]	validation_0-quantile:0.02499
# [188]	validation_0-quantile:0.02497
# [189]	validation_0-quantile:0.02495
# [190]	validation_0-quantile:0.02492
# [191]	validation_0-quantile:0.02490
# [192]	validation_0-quantile:0.02487
# [193]	validation_0-quantile:0.02487
# [194]	validation_0-quantile:0.02487
# [195]	validation_0-quantile:0.02478
# [196]	validation_0-quantile:0.02479
# [197]	validation_0-quantile:0.02477
# [198]	validation_0-quantile:0.02475
# [199]	validation_0-quantile:0.02472
# [200]	validation_0-quantile:0.02470
# [201]	validation_0-quantile:0.02466
# [202]	validation_0-quantile:0.02465
# [203]	validation_0-quantile:0.02465
# [204]	validation_0-quantile:0.02463
# [205]	validation_0-quantile:0.02461
# [206]	validation_0-quantile:0.02459
# [207]	validation_0-quantile:0.02457
# [208]	validation_0-quantile:0.02455
# [209]	validation_0-quantile:0.02454
# [210]	validation_0-quantile:0.02452
# [211]	validation_0-quantile:0.02451
# [212]	validation_0-quantile:0.02448
# [213]	validation_0-quantile:0.02447
# [214]	validation_0-quantile:0.02444
# [215]	validation_0-quantile:0.02448
# [216]	validation_0-quantile:0.02447
# [217]	validation_0-quantile:0.02445
# [218]	validation_0-quantile:0.02443
# [219]	validation_0-quantile:0.02447
# [220]	validation_0-quantile:0.02445
# [221]	validation_0-quantile:0.02443
# [222]	validation_0-quantile:0.02442
# [223]	validation_0-quantile:0.02441
# [224]	validation_0-quantile:0.02439
# [225]	validation_0-quantile:0.02437
# [226]	validation_0-quantile:0.02435
# [227]	validation_0-quantile:0.02433
# [228]	validation_0-quantile:0.02432
# [229]	validation_0-quantile:0.02430
# [230]	validation_0-quantile:0.02428
# [231]	validation_0-quantile:0.02427
# [232]	validation_0-quantile:0.02425
# [233]	validation_0-quantile:0.02424
# [234]	validation_0-quantile:0.02423
# [235]	validation_0-quantile:0.02422
# [236]	validation_0-quantile:0.02421
# [237]	validation_0-quantile:0.02419
# [238]	validation_0-quantile:0.02417
# [239]	validation_0-quantile:0.02416
# [240]	validation_0-quantile:0.02415
# [241]	validation_0-quantile:0.02414
# [242]	validation_0-quantile:0.02413
# [243]	validation_0-quantile:0.02412
# [244]	validation_0-quantile:0.02411
# [245]	validation_0-quantile:0.02410
# [246]	validation_0-quantile:0.02409
# [247]	validation_0-quantile:0.02408
# [248]	validation_0-quantile:0.02409
# [249]	validation_0-quantile:0.02407
# [250]	validation_0-quantile:0.02406
# [251]	validation_0-quantile:0.02404
# [252]	validation_0-quantile:0.02403
# [253]	validation_0-quantile:0.02401
# [254]	validation_0-quantile:0.02400
# [255]	validation_0-quantile:0.02399
# [256]	validation_0-quantile:0.02398
# [257]	validation_0-quantile:0.02397
# [258]	validation_0-quantile:0.02396
# [259]	validation_0-quantile:0.02395
# [260]	validation_0-quantile:0.02394
# [261]	validation_0-quantile:0.02393
# [262]	validation_0-quantile:0.02391
# [263]	validation_0-quantile:0.02390
# [264]	validation_0-quantile:0.02390
# [265]	validation_0-quantile:0.02388
# [266]	validation_0-quantile:0.02387
# [267]	validation_0-quantile:0.02386
# [268]	validation_0-quantile:0.02385
# [269]	validation_0-quantile:0.02384
# [270]	validation_0-quantile:0.02382
# [271]	validation_0-quantile:0.02381
# [272]	validation_0-quantile:0.02380
# [273]	validation_0-quantile:0.02380
# [274]	validation_0-quantile:0.02379
# [275]	validation_0-quantile:0.02377
# [276]	validation_0-quantile:0.02376
# [277]	validation_0-quantile:0.02375
# [278]	validation_0-quantile:0.02375
# [279]	validation_0-quantile:0.02375
# [280]	validation_0-quantile:0.02375
# [281]	validation_0-quantile:0.02374
# [282]	validation_0-quantile:0.02373
# [283]	validation_0-quantile:0.02372
# [284]	validation_0-quantile:0.02371
# [285]	validation_0-quantile:0.02369
# [286]	validation_0-quantile:0.02368
# [287]	validation_0-quantile:0.02368
# [288]	validation_0-quantile:0.02367
# [289]	validation_0-quantile:0.02367
# [290]	validation_0-quantile:0.02366
# [291]	validation_0-quantile:0.02365
# [292]	validation_0-quantile:0.02365
# [293]	validation_0-quantile:0.02364
# [294]	validation_0-quantile:0.02363
# [295]	validation_0-quantile:0.02362
# [296]	validation_0-quantile:0.02359
# [297]	validation_0-quantile:0.02357
# [298]	validation_0-quantile:0.02357
# [299]	validation_0-quantile:0.02356
# [300]	validation_0-quantile:0.02355
# [301]	validation_0-quantile:0.02355
# [302]	validation_0-quantile:0.02354
# [303]	validation_0-quantile:0.02353
# [304]	validation_0-quantile:0.02352
# [305]	validation_0-quantile:0.02352
# [306]	validation_0-quantile:0.02351
# [307]	validation_0-quantile:0.02350
# [308]	validation_0-quantile:0.02350
# [309]	validation_0-quantile:0.02349
# [310]	validation_0-quantile:0.02348
# [311]	validation_0-quantile:0.02348
# [312]	validation_0-quantile:0.02347
# [313]	validation_0-quantile:0.02347
# [314]	validation_0-quantile:0.02347
# [315]	validation_0-quantile:0.02347
# [316]	validation_0-quantile:0.02346
# [317]	validation_0-quantile:0.02345
# [318]	validation_0-quantile:0.02345
# [319]	validation_0-quantile:0.02344
# [320]	validation_0-quantile:0.02344
# [321]	validation_0-quantile:0.02344
# [322]	validation_0-quantile:0.02343
# [323]	validation_0-quantile:0.02342
# [324]	validation_0-quantile:0.02341
# [325]	validation_0-quantile:0.02340
# [326]	validation_0-quantile:0.02340
# [327]	validation_0-quantile:0.02339
# [328]	validation_0-quantile:0.02339
# [329]	validation_0-quantile:0.02339
# [330]	validation_0-quantile:0.02338
# [331]	validation_0-quantile:0.02337
# [332]	validation_0-quantile:0.02337
# [333]	validation_0-quantile:0.02336
# [334]	validation_0-quantile:0.02336
# [335]	validation_0-quantile:0.02336
# [336]	validation_0-quantile:0.02335
# [337]	validation_0-quantile:0.02334
# [338]	validation_0-quantile:0.02333
# [339]	validation_0-quantile:0.02333
# [340]	validation_0-quantile:0.02332
# [341]	validation_0-quantile:0.02332
# [342]	validation_0-quantile:0.02332
# [343]	validation_0-quantile:0.02331
# [344]	validation_0-quantile:0.02331
# [345]	validation_0-quantile:0.02330
# [346]	validation_0-quantile:0.02329
# [347]	validation_0-quantile:0.02329
# [348]	validation_0-quantile:0.02328
# [349]	validation_0-quantile:0.02328
# [350]	validation_0-quantile:0.02327
# [351]	validation_0-quantile:0.02327
# [352]	validation_0-quantile:0.02326
# [353]	validation_0-quantile:0.02325
# [354]	validation_0-quantile:0.02325
# [355]	validation_0-quantile:0.02326
# [356]	validation_0-quantile:0.02325
# [357]	validation_0-quantile:0.02325
# [358]	validation_0-quantile:0.02324
# [359]	validation_0-quantile:0.02324
# [360]	validation_0-quantile:0.02323
# [361]	validation_0-quantile:0.02323
# [362]	validation_0-quantile:0.02330
# [363]	validation_0-quantile:0.02330
# [364]	validation_0-quantile:0.02329
# [365]	validation_0-quantile:0.02329
# [366]	validation_0-quantile:0.02329
# [367]	validation_0-quantile:0.02328
# [368]	validation_0-quantile:0.02328
# [369]	validation_0-quantile:0.02327
# [370]	validation_0-quantile:0.02327
# [371]	validation_0-quantile:0.02327
# [372]	validation_0-quantile:0.02327
# [373]	validation_0-quantile:0.02326
# [374]	validation_0-quantile:0.02326
# [375]	validation_0-quantile:0.02326
# [376]	validation_0-quantile:0.02325
# [377]	validation_0-quantile:0.02325
# [378]	validation_0-quantile:0.02324
# [379]	validation_0-quantile:0.02324
# [380]	validation_0-quantile:0.02323
# [381]	validation_0-quantile:0.02323
# [382]	validation_0-quantile:0.02323
# [383]	validation_0-quantile:0.02322
# [384]	validation_0-quantile:0.02322
# [385]	validation_0-quantile:0.02321
# [386]	validation_0-quantile:0.02321
# [387]	validation_0-quantile:0.02321
# [388]	validation_0-quantile:0.02321
# [389]	validation_0-quantile:0.02320
# [390]	validation_0-quantile:0.02320
# [391]	validation_0-quantile:0.02319
# [392]	validation_0-quantile:0.02319
# [393]	validation_0-quantile:0.02319
# [394]	validation_0-quantile:0.02319
# [395]	validation_0-quantile:0.02318
# [396]	validation_0-quantile:0.02318
# [397]	validation_0-quantile:0.02318
# [398]	validation_0-quantile:0.02318
# [399]	validation_0-quantile:0.02317
# [400]	validation_0-quantile:0.02317
# [401]	validation_0-quantile:0.02316
# [402]	validation_0-quantile:0.02316
# [403]	validation_0-quantile:0.02316
# [404]	validation_0-quantile:0.02315
# [405]	validation_0-quantile:0.02315
# [406]	validation_0-quantile:0.02315
# [407]	validation_0-quantile:0.02315
# [408]	validation_0-quantile:0.02315
# [409]	validation_0-quantile:0.02314
# [410]	validation_0-quantile:0.02314
# [411]	validation_0-quantile:0.02313
# [412]	validation_0-quantile:0.02313
# [413]	validation_0-quantile:0.02313
# [414]	validation_0-quantile:0.02313
# [415]	validation_0-quantile:0.02312
# [416]	validation_0-quantile:0.02312
# [417]	validation_0-quantile:0.02312
# [418]	validation_0-quantile:0.02311
# [419]	validation_0-quantile:0.02311
# [420]	validation_0-quantile:0.02311
# [421]	validation_0-quantile:0.02311
# [422]	validation_0-quantile:0.02311
# [423]	validation_0-quantile:0.02310
# [424]	validation_0-quantile:0.02310
# [425]	validation_0-quantile:0.02310
# [426]	validation_0-quantile:0.02310
# [427]	validation_0-quantile:0.02310
# [428]	validation_0-quantile:0.02310
# [429]	validation_0-quantile:0.02309
# [430]	validation_0-quantile:0.02309
# [431]	validation_0-quantile:0.02309
# [432]	validation_0-quantile:0.02309
# [433]	validation_0-quantile:0.02308
# [434]	validation_0-quantile:0.02308
# [435]	validation_0-quantile:0.02308
# [436]	validation_0-quantile:0.02308
# [437]	validation_0-quantile:0.02307
# [438]	validation_0-quantile:0.02307
# [439]	validation_0-quantile:0.02307
# [440]	validation_0-quantile:0.02307
# [441]	validation_0-quantile:0.02307
# [442]	validation_0-quantile:0.02306
# [443]	validation_0-quantile:0.02306
# [444]	validation_0-quantile:0.02306
# [445]	validation_0-quantile:0.02305
# [446]	validation_0-quantile:0.02305
# [447]	validation_0-quantile:0.02305
# [448]	validation_0-quantile:0.02305
# [449]	validation_0-quantile:0.02304
# [450]	validation_0-quantile:0.02304
# [451]	validation_0-quantile:0.02304
# [452]	validation_0-quantile:0.02303
# [453]	validation_0-quantile:0.02303
# [454]	validation_0-quantile:0.02302
# [455]	validation_0-quantile:0.02302
# [456]	validation_0-quantile:0.02302
# [457]	validation_0-quantile:0.02302
# [458]	validation_0-quantile:0.02302
# [459]	validation_0-quantile:0.02302
# [460]	validation_0-quantile:0.02301
# [461]	validation_0-quantile:0.02301
# [462]	validation_0-quantile:0.02301
# [463]	validation_0-quantile:0.02301
# [464]	validation_0-quantile:0.02300
# [465]	validation_0-quantile:0.02300
# [466]	validation_0-quantile:0.02300
# [467]	validation_0-quantile:0.02300
# [468]	validation_0-quantile:0.02299
# [469]	validation_0-quantile:0.02299
# [470]	validation_0-quantile:0.02299
# [471]	validation_0-quantile:0.02299
# [472]	validation_0-quantile:0.02298
# [473]	validation_0-quantile:0.02298
# [474]	validation_0-quantile:0.02298
# [475]	validation_0-quantile:0.02298
# [476]	validation_0-quantile:0.02298
# [477]	validation_0-quantile:0.02297
# [478]	validation_0-quantile:0.02297
# [479]	validation_0-quantile:0.02297
# [480]	validation_0-quantile:0.02296
# [481]	validation_0-quantile:0.02296
# [482]	validation_0-quantile:0.02295
# [483]	validation_0-quantile:0.02295
# [484]	validation_0-quantile:0.02295
# [485]	validation_0-quantile:0.02295
# [486]	validation_0-quantile:0.02294
# [487]	validation_0-quantile:0.02294
# [488]	validation_0-quantile:0.02294
# [489]	validation_0-quantile:0.02294
# [490]	validation_0-quantile:0.02293
# [491]	validation_0-quantile:0.02293
# [492]	validation_0-quantile:0.02293
# [493]	validation_0-quantile:0.02292
# [494]	validation_0-quantile:0.02292
# [495]	validation_0-quantile:0.02292
# [496]	validation_0-quantile:0.02292
# [497]	validation_0-quantile:0.02292
# [498]	validation_0-quantile:0.02292
# [499]	validation_0-quantile:0.02292
# [500]	validation_0-quantile:0.02292
# [501]	validation_0-quantile:0.02292
# [502]	validation_0-quantile:0.02292
# [503]	validation_0-quantile:0.02292
# [504]	validation_0-quantile:0.02292
# [505]	validation_0-quantile:0.02292
# [506]	validation_0-quantile:0.02292
# [507]	validation_0-quantile:0.02291
# [508]	validation_0-quantile:0.02291
# [509]	validation_0-quantile:0.02291
# [510]	validation_0-quantile:0.02291
# [511]	validation_0-quantile:0.02291
# [512]	validation_0-quantile:0.02291
# [513]	validation_0-quantile:0.02291
# [514]	validation_0-quantile:0.02291
# [515]	validation_0-quantile:0.02291
# [516]	validation_0-quantile:0.02290
# [517]	validation_0-quantile:0.02290
# [518]	validation_0-quantile:0.02290
# [519]	validation_0-quantile:0.02290
# [520]	validation_0-quantile:0.02290
# [521]	validation_0-quantile:0.02290
# [522]	validation_0-quantile:0.02290
# [523]	validation_0-quantile:0.02290
# [524]	validation_0-quantile:0.02290
# [525]	validation_0-quantile:0.02290
# [526]	validation_0-quantile:0.02290
# [527]	validation_0-quantile:0.02290
# [528]	validation_0-quantile:0.02290
# [529]	validation_0-quantile:0.02290
# [530]	validation_0-quantile:0.02290
# [531]	validation_0-quantile:0.02290
# [532]	validation_0-quantile:0.02290
# [533]	validation_0-quantile:0.02289
# [534]	validation_0-quantile:0.02289
# [535]	validation_0-quantile:0.02289
# [536]	validation_0-quantile:0.02289
# [537]	validation_0-quantile:0.02289
# [538]	validation_0-quantile:0.02289
# [539]	validation_0-quantile:0.02289
# [540]	validation_0-quantile:0.02288
# [541]	validation_0-quantile:0.02288
# [542]	validation_0-quantile:0.02288
# [543]	validation_0-quantile:0.02288
# [544]	validation_0-quantile:0.02288
# [545]	validation_0-quantile:0.02288
# [546]	validation_0-quantile:0.02288
# [547]	validation_0-quantile:0.02288
# [548]	validation_0-quantile:0.02288
# [549]	validation_0-quantile:0.02288
# [550]	validation_0-quantile:0.02288
# [551]	validation_0-quantile:0.02287
# [552]	validation_0-quantile:0.02287
# [553]	validation_0-quantile:0.02287
# [554]	validation_0-quantile:0.02287
# [555]	validation_0-quantile:0.02287
# [556]	validation_0-quantile:0.02287
# [557]	validation_0-quantile:0.02287
# [558]	validation_0-quantile:0.02287
# [559]	validation_0-quantile:0.02287
# [560]	validation_0-quantile:0.02287
# [561]	validation_0-quantile:0.02286
# [562]	validation_0-quantile:0.02287
# [563]	validation_0-quantile:0.02286
# [564]	validation_0-quantile:0.02286
# [565]	validation_0-quantile:0.02286
# [566]	validation_0-quantile:0.02286
# [567]	validation_0-quantile:0.02287
# [568]	validation_0-quantile:0.02287
# [569]	validation_0-quantile:0.02287
# [570]	validation_0-quantile:0.02286
# [571]	validation_0-quantile:0.02287
# [572]	validation_0-quantile:0.02286
# [573]	validation_0-quantile:0.02287
# [574]	validation_0-quantile:0.02287
# [575]	validation_0-quantile:0.02286
# [576]	validation_0-quantile:0.02286
# [577]	validation_0-quantile:0.02287
# [578]	validation_0-quantile:0.02287
# [579]	validation_0-quantile:0.02287
# [580]	validation_0-quantile:0.02287
# [581]	validation_0-quantile:0.02287
# [582]	validation_0-quantile:0.02287
# [583]	validation_0-quantile:0.02287
# [584]	validation_0-quantile:0.02287
# [585]	validation_0-quantile:0.02287
# [586]	validation_0-quantile:0.02287
# [587]	validation_0-quantile:0.02287
# [588]	validation_0-quantile:0.02286
# [589]	validation_0-quantile:0.02286
# [590]	validation_0-quantile:0.02286
# [591]	validation_0-quantile:0.02286
# [592]	validation_0-quantile:0.02286
# [593]	validation_0-quantile:0.02286
# [594]	validation_0-quantile:0.02286
# [595]	validation_0-quantile:0.02286
# [596]	validation_0-quantile:0.02286
# [597]	validation_0-quantile:0.02286
# [598]	validation_0-quantile:0.02286
# [599]	validation_0-quantile:0.02286
# [600]	validation_0-quantile:0.02286
# [601]	validation_0-quantile:0.02286
# [602]	validation_0-quantile:0.02286
# [603]	validation_0-quantile:0.02286
# [604]	validation_0-quantile:0.02286
# [605]	validation_0-quantile:0.02286
# [606]	validation_0-quantile:0.02286
# [607]	validation_0-quantile:0.02286
# [608]	validation_0-quantile:0.02286
# [609]	validation_0-quantile:0.02286
# [610]	validation_0-quantile:0.02286
# [611]	validation_0-quantile:0.02286
# [612]	validation_0-quantile:0.02286
# [613]	validation_0-quantile:0.02286
# [614]	validation_0-quantile:0.02286
# [615]	validation_0-quantile:0.02286
# [616]	validation_0-quantile:0.02286
# [617]	validation_0-quantile:0.02286
# [618]	validation_0-quantile:0.02287
# [619]	validation_0-quantile:0.02287
# [620]	validation_0-quantile:0.02287
# [621]	validation_0-quantile:0.02287
# [622]	validation_0-quantile:0.02286
# [623]	validation_0-quantile:0.02286
# [624]	validation_0-quantile:0.02286
# [625]	validation_0-quantile:0.02285
# [626]	validation_0-quantile:0.02285
# [627]	validation_0-quantile:0.02285
# [628]	validation_0-quantile:0.02285
# [629]	validation_0-quantile:0.02285
# [630]	validation_0-quantile:0.02285
# [631]	validation_0-quantile:0.02285
# [632]	validation_0-quantile:0.02285
# [633]	validation_0-quantile:0.02285
# [634]	validation_0-quantile:0.02285
# [635]	validation_0-quantile:0.02285
# [636]	validation_0-quantile:0.02285
# [637]	validation_0-quantile:0.02285
# [638]	validation_0-quantile:0.02285
# [639]	validation_0-quantile:0.02285
# [640]	validation_0-quantile:0.02285
# [641]	validation_0-quantile:0.02285
# [642]	validation_0-quantile:0.02285
# [643]	validation_0-quantile:0.02286
# [644]	validation_0-quantile:0.02285
# [645]	validation_0-quantile:0.02286
# [646]	validation_0-quantile:0.02286
# [647]	validation_0-quantile:0.02286
# [648]	validation_0-quantile:0.02286
# [649]	validation_0-quantile:0.02286
# [650]	validation_0-quantile:0.02285
# [651]	validation_0-quantile:0.02285
# [652]	validation_0-quantile:0.02286
# [653]	validation_0-quantile:0.02286
# [654]	validation_0-quantile:0.02286
# [655]	validation_0-quantile:0.02286
# [656]	validation_0-quantile:0.02286
# [657]	validation_0-quantile:0.02286
# [658]	validation_0-quantile:0.02286
# [659]	validation_0-quantile:0.02286
# [660]	validation_0-quantile:0.02286
# [661]	validation_0-quantile:0.02286
# [662]	validation_0-quantile:0.02286
# [663]	validation_0-quantile:0.02286
# [664]	validation_0-quantile:0.02285
# [665]	validation_0-quantile:0.02285
# [666]	validation_0-quantile:0.02286
# [667]	validation_0-quantile:0.02285
# [668]	validation_0-quantile:0.02285
# [669]	validation_0-quantile:0.02285
# [670]	validation_0-quantile:0.02286
# [671]	validation_0-quantile:0.02286
# [672]	validation_0-quantile:0.02286
# [673]	validation_0-quantile:0.02285
# [674]	validation_0-quantile:0.02286
# [675]	validation_0-quantile:0.02286
# [676]	validation_0-quantile:0.02286
# [677]	validation_0-quantile:0.02286
# [678]	validation_0-quantile:0.02286
# [679]	validation_0-quantile:0.02285
# [680]	validation_0-quantile:0.02285
# [681]	validation_0-quantile:0.02285
# [682]	validation_0-quantile:0.02285
# [683]	validation_0-quantile:0.02285
# [684]	validation_0-quantile:0.02285
# [685]	validation_0-quantile:0.02285
# [686]	validation_0-quantile:0.02285
# [687]	validation_0-quantile:0.02285
# [688]	validation_0-quantile:0.02285
# [689]	validation_0-quantile:0.02285
# [690]	validation_0-quantile:0.02285
# [691]	validation_0-quantile:0.02285
# [692]	validation_0-quantile:0.02285
# [693]	validation_0-quantile:0.02285
# [694]	validation_0-quantile:0.02286
# [695]	validation_0-quantile:0.02286
# [696]	validation_0-quantile:0.02286
# [697]	validation_0-quantile:0.02286
# [698]	validation_0-quantile:0.02286
# [699]	validation_0-quantile:0.02286
# [700]	validation_0-quantile:0.02287
# [701]	validation_0-quantile:0.02287
# [702]	validation_0-quantile:0.02287
# [703]	validation_0-quantile:0.02287
# [704]	validation_0-quantile:0.02287
# [705]	validation_0-quantile:0.02287
# [706]	validation_0-quantile:0.02287
# [707]	validation_0-quantile:0.02287
# [708]	validation_0-quantile:0.02287
# [709]	validation_0-quantile:0.02287
# [710]	validation_0-quantile:0.02287
# [711]	validation_0-quantile:0.02287
# [712]	validation_0-quantile:0.02287
# [713]	validation_0-quantile:0.02287
# [714]	validation_0-quantile:0.02287
# [715]	validation_0-quantile:0.02287
# [716]	validation_0-quantile:0.02287
# [717]	validation_0-quantile:0.02287
# [718]	validation_0-quantile:0.02287
# [719]	validation_0-quantile:0.02287
# [720]	validation_0-quantile:0.02287
# [721]	validation_0-quantile:0.02287
# [722]	validation_0-quantile:0.02287
# [723]	validation_0-quantile:0.02287
# [724]	validation_0-quantile:0.02287
# [725]	validation_0-quantile:0.02287
# [726]	validation_0-quantile:0.02287
# [727]	validation_0-quantile:0.02287
# [728]	validation_0-quantile:0.02287
# [729]	validation_0-quantile:0.02287
# [730]	validation_0-quantile:0.02287
# [731]	validation_0-quantile:0.02287
# [732]	validation_0-quantile:0.02287
# [733]	validation_0-quantile:0.02288
# [734]	validation_0-quantile:0.02288
# [735]	validation_0-quantile:0.02288
# [736]	validation_0-quantile:0.02288
# [737]	validation_0-quantile:0.02288
# [738]	validation_0-quantile:0.02288
# [739]	validation_0-quantile:0.02288
# [740]	validation_0-quantile:0.02288
# [741]	validation_0-quantile:0.02288
# [742]	validation_0-quantile:0.02289
# [743]	validation_0-quantile:0.02289
# [744]	validation_0-quantile:0.02289
# [745]	validation_0-quantile:0.02289
# [746]	validation_0-quantile:0.02289
# [747]	validation_0-quantile:0.02289
# [748]	validation_0-quantile:0.02289
# [749]	validation_0-quantile:0.02289
# [750]	validation_0-quantile:0.02289
# [751]	validation_0-quantile:0.02289
# [752]	validation_0-quantile:0.02289
# [753]	validation_0-quantile:0.02289
# [754]	validation_0-quantile:0.02289
# [755]	validation_0-quantile:0.02289
# [756]	validation_0-quantile:0.02289
# [757]	validation_0-quantile:0.02289
# [758]	validation_0-quantile:0.02289
# [759]	validation_0-quantile:0.02289
# [760]	validation_0-quantile:0.02289
# [761]	validation_0-quantile:0.02289
# [762]	validation_0-quantile:0.02289
# [763]	validation_0-quantile:0.02289
# [764]	validation_0-quantile:0.02289
# [765]	validation_0-quantile:0.02289
# [766]	validation_0-quantile:0.02289
# [767]	validation_0-quantile:0.02289
# [768]	validation_0-quantile:0.02289
# [769]	validation_0-quantile:0.02289
# [770]	validation_0-quantile:0.02289
# [771]	validation_0-quantile:0.02289
# [772]	validation_0-quantile:0.02289
# [773]	validation_0-quantile:0.02289
# [774]	validation_0-quantile:0.02289
# [775]	validation_0-quantile:0.02290
# [776]	validation_0-quantile:0.02290
# [777]	validation_0-quantile:0.02290
# [778]	validation_0-quantile:0.02290
# [779]	validation_0-quantile:0.02290
# [780]	validation_0-quantile:0.02291
# [781]	validation_0-quantile:0.02291
# [782]	validation_0-quantile:0.02291
# [783]	validation_0-quantile:0.02291
# [784]	validation_0-quantile:0.02291
# [785]	validation_0-quantile:0.02291
# [786]	validation_0-quantile:0.02291
# [787]	validation_0-quantile:0.02291
# [788]	validation_0-quantile:0.02291
# [789]	validation_0-quantile:0.02291
# [790]	validation_0-quantile:0.02291
# [791]	validation_0-quantile:0.02291
# [792]	validation_0-quantile:0.02289
# [793]	validation_0-quantile:0.02289
# [794]	validation_0-quantile:0.02289
# [795]	validation_0-quantile:0.02289
# [796]	validation_0-quantile:0.02289
# [797]	validation_0-quantile:0.02289
# [798]	validation_0-quantile:0.02289
# [799]	validation_0-quantile:0.02289
# [800]	validation_0-quantile:0.02289
# [801]	validation_0-quantile:0.02289
# [802]	validation_0-quantile:0.02289
# [803]	validation_0-quantile:0.02289
# [804]	validation_0-quantile:0.02289
# [805]	validation_0-quantile:0.02290
# [806]	validation_0-quantile:0.02290
# [807]	validation_0-quantile:0.02290
# [808]	validation_0-quantile:0.02290
# [809]	validation_0-quantile:0.02290
# [810]	validation_0-quantile:0.02290
# [811]	validation_0-quantile:0.02290
# [812]	validation_0-quantile:0.02290
# [813]	validation_0-quantile:0.02290
# [814]	validation_0-quantile:0.02291
# [815]	validation_0-quantile:0.02291
# [816]	validation_0-quantile:0.02291
# [817]	validation_0-quantile:0.02291
# [818]	validation_0-quantile:0.02291
# [819]	validation_0-quantile:0.02291
# [820]	validation_0-quantile:0.02291
# [821]	validation_0-quantile:0.02291
# [822]	validation_0-quantile:0.02291
# [823]	validation_0-quantile:0.02289
# [824]	validation_0-quantile:0.02289
# [825]	validation_0-quantile:0.02289
# [826]	validation_0-quantile:0.02289
# [827]	validation_0-quantile:0.02289
# [828]	validation_0-quantile:0.02289
# [829]	validation_0-quantile:0.02289
# [830]	validation_0-quantile:0.02289
# [831]	validation_0-quantile:0.02289
# [832]	validation_0-quantile:0.02289
# [833]	validation_0-quantile:0.02289
# [834]	validation_0-quantile:0.02289
# [835]	validation_0-quantile:0.02289
# [836]	validation_0-quantile:0.02289
# [837]	validation_0-quantile:0.02289
# [838]	validation_0-quantile:0.02289
# [839]	validation_0-quantile:0.02289
# [840]	validation_0-quantile:0.02289
# [841]	validation_0-quantile:0.02290
# [842]	validation_0-quantile:0.02290
# [843]	validation_0-quantile:0.02290
# [844]	validation_0-quantile:0.02290
# [845]	validation_0-quantile:0.02290
# [846]	validation_0-quantile:0.02290
# [847]	validation_0-quantile:0.02290
# [848]	validation_0-quantile:0.02290
# [849]	validation_0-quantile:0.02290
# [850]	validation_0-quantile:0.02290
# [851]	validation_0-quantile:0.02290
# [852]	validation_0-quantile:0.02290
# [853]	validation_0-quantile:0.02290
# [854]	validation_0-quantile:0.02290
# [855]	validation_0-quantile:0.02290
# [856]	validation_0-quantile:0.02290
# [857]	validation_0-quantile:0.02290
# [858]	validation_0-quantile:0.02290
# [859]	validation_0-quantile:0.02290
# [860]	validation_0-quantile:0.02291
# [861]	validation_0-quantile:0.02291
# [862]	validation_0-quantile:0.02291
# [863]	validation_0-quantile:0.02291
# [864]	validation_0-quantile:0.02291
# [865]	validation_0-quantile:0.02291
# [866]	validation_0-quantile:0.02291
# [867]	validation_0-quantile:0.02291
# [868]	validation_0-quantile:0.02291
# [869]	validation_0-quantile:0.02291
# [870]	validation_0-quantile:0.02291
# [871]	validation_0-quantile:0.02291
# [872]	validation_0-quantile:0.02291
# [873]	validation_0-quantile:0.02291
# [874]	validation_0-quantile:0.02291
# [875]	validation_0-quantile:0.02291
# [876]	validation_0-quantile:0.02291
# [877]	validation_0-quantile:0.02291
# [878]	validation_0-quantile:0.02291
# [879]	validation_0-quantile:0.02292
# [880]	validation_0-quantile:0.02292
# [881]	validation_0-quantile:0.02292
# [882]	validation_0-quantile:0.02292
# [883]	validation_0-quantile:0.02292
# [884]	validation_0-quantile:0.02292
# [885]	validation_0-quantile:0.02292
# [886]	validation_0-quantile:0.02292
# [887]	validation_0-quantile:0.02292
# [888]	validation_0-quantile:0.02292
# [889]	validation_0-quantile:0.02292
# [890]	validation_0-quantile:0.02292
# [891]	validation_0-quantile:0.02292
# [892]	validation_0-quantile:0.02292
# [893]	validation_0-quantile:0.02292
# [894]	validation_0-quantile:0.02292
# [895]	validation_0-quantile:0.02292
# [896]	validation_0-quantile:0.02292
# [897]	validation_0-quantile:0.02292
# [898]	validation_0-quantile:0.02292
# [899]	validation_0-quantile:0.02292
# [900]	validation_0-quantile:0.02292
# [901]	validation_0-quantile:0.02292
# [902]	validation_0-quantile:0.02292
# [903]	validation_0-quantile:0.02291
# [904]	validation_0-quantile:0.02291
# [905]	validation_0-quantile:0.02291
# [906]	validation_0-quantile:0.02291
# [907]	validation_0-quantile:0.02291
# [908]	validation_0-quantile:0.02291
# [909]	validation_0-quantile:0.02291
# [910]	validation_0-quantile:0.02291
# [911]	validation_0-quantile:0.02291
# [912]	validation_0-quantile:0.02291
# [913]	validation_0-quantile:0.02291
# [914]	validation_0-quantile:0.02291
# [915]	validation_0-quantile:0.02291
# [916]	validation_0-quantile:0.02291
# [917]	validation_0-quantile:0.02291
# [918]	validation_0-quantile:0.02291
# [919]	validation_0-quantile:0.02291
# [920]	validation_0-quantile:0.02291
# [921]	validation_0-quantile:0.02291
# [922]	validation_0-quantile:0.02291
# [923]	validation_0-quantile:0.02291
# [924]	validation_0-quantile:0.02291
# [925]	validation_0-quantile:0.02291
# [926]	validation_0-quantile:0.02291
# [927]	validation_0-quantile:0.02291
# [928]	validation_0-quantile:0.02291
# [929]	validation_0-quantile:0.02291
# [930]	validation_0-quantile:0.02291
# [931]	validation_0-quantile:0.02291
# [932]	validation_0-quantile:0.02291
# [933]	validation_0-quantile:0.02291
# [934]	validation_0-quantile:0.02291
# [935]	validation_0-quantile:0.02291
# [936]	validation_0-quantile:0.02291
# [937]	validation_0-quantile:0.02291
# [938]	validation_0-quantile:0.02291
# [939]	validation_0-quantile:0.02291
# [940]	validation_0-quantile:0.02291
# [941]	validation_0-quantile:0.02291
# [942]	validation_0-quantile:0.02291
# [943]	validation_0-quantile:0.02291
# [944]	validation_0-quantile:0.02291
# [945]	validation_0-quantile:0.02291
# [946]	validation_0-quantile:0.02291
# [947]	validation_0-quantile:0.02291
# [948]	validation_0-quantile:0.02292
# [949]	validation_0-quantile:0.02292
# [950]	validation_0-quantile:0.02292
# [951]	validation_0-quantile:0.02292
# [952]	validation_0-quantile:0.02292
# [953]	validation_0-quantile:0.02292
# [954]	validation_0-quantile:0.02292
# [955]	validation_0-quantile:0.02292
# [956]	validation_0-quantile:0.02292
# [957]	validation_0-quantile:0.02292
# [958]	validation_0-quantile:0.02292
# [959]	validation_0-quantile:0.02292
# [960]	validation_0-quantile:0.02292
# [961]	validation_0-quantile:0.02292
# [962]	validation_0-quantile:0.02292
# [963]	validation_0-quantile:0.02292
# [964]	validation_0-quantile:0.02292
# [965]	validation_0-quantile:0.02292
# [966]	validation_0-quantile:0.02292
# [967]	validation_0-quantile:0.02292
# [968]	validation_0-quantile:0.02292
# [969]	validation_0-quantile:0.02292
# [970]	validation_0-quantile:0.02292
# [971]	validation_0-quantile:0.02292
# [972]	validation_0-quantile:0.02292
# [973]	validation_0-quantile:0.02292
# [974]	validation_0-quantile:0.02293
# [975]	validation_0-quantile:0.02293
# [976]	validation_0-quantile:0.02293
# [977]	validation_0-quantile:0.02293
# [978]	validation_0-quantile:0.02293
# [979]	validation_0-quantile:0.02292
# [980]	validation_0-quantile:0.02292
# [981]	validation_0-quantile:0.02292
# [982]	validation_0-quantile:0.02292
# [983]	validation_0-quantile:0.02292
# [984]	validation_0-quantile:0.02292
# [985]	validation_0-quantile:0.02292
# [986]	validation_0-quantile:0.02292
# [987]	validation_0-quantile:0.02292
# [988]	validation_0-quantile:0.02292
# [989]	validation_0-quantile:0.02292
# [990]	validation_0-quantile:0.02292
# [991]	validation_0-quantile:0.02292
# [992]	validation_0-quantile:0.02292
# [993]	validation_0-quantile:0.02292
# [994]	validation_0-quantile:0.02292
# [995]	validation_0-quantile:0.02292
# [996]	validation_0-quantile:0.02292
# [997]	validation_0-quantile:0.02292
# [998]	validation_0-quantile:0.02292
# [999]	validation_0-quantile:0.02292
# MAE: 569534.4924061605
# RMSE: 1414932.66934115
# Pearson_Correlation: 0.8645848804428959
# Spearman_Correlation: 0.8407333006484867
# Nash_Sutcliffe_Efficiency: 0.7403778946041149
# Kling_Gupta_Efficiency: 0.7906370364403479
# RMSE_Extreme: 5055734.1776766265

# %%
### Plot Results
plt.figure(figsize=(12, 6))
plt.plot(y_test_denorm, label='Observed')
#plt.plot(lstm_preds, label='LSTM Predictions', linestyle='--')
plt.plot(best_xgb_preds, label='XGBoost Predictions', linestyle='--',alpha=0.5)
#plt.plot(gru_preds, label='GRU Predictions', linestyle='--')
#plt.plot(persistence_preds, label='Persistence Predictions', linestyle='-')
plt.legend()
plt.title('Model Comparison: Predictions vs Observed')
plt.ylabel('Streamflow')
plt.xlabel('Time')
plt.show()

# %%
import shap
# Use the SHAP explainer
explainer = shap.Explainer(best_xgb_model)
shap_values = explainer(X_test_xg)

# Summary plot with feature names
shap.summary_plot(shap_values, X_test_xg, feature_names=features_lstm)

# Force plot for an individual prediction (adjust the index for a specific instance)
instance_index = 1050
shap.force_plot(explainer.expected_value, shap_values.values[instance_index], X_test_xg[instance_index], feature_names=features_lstm)
# Out:
# <div id='iTM917T2HYQHJ9RJ3XXYP'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.08047379553318024, "outValue": -0.22319267690181732, "link": "identity", "featureNames": ["flow_lag1", "flow_lag2", "flow_lag3", "flow_lag4", "flow_lag5", "lb_storage_lag1", "lb_storage_lag2", "lb_storage_lag3", "ami_storage_lag1", "ami_storage_lag2", "ami_storage_lag3", "falc_storage_lag1", "falc_storage_lag2", "falc_storage_lag3", "non_tc_lag1", "non_tc_lag2", "non_tc_lag3", "non_tc_lag4", "non_tc_lag5", "tc_lag1", "tc_lag2", "tc_lag3", "tc_lag4", "tc_lag5"], "features": {"0": {"effect": -0.20627814531326294, "value": -0.22342870366399792}, "1": {"effect": 0.02203020453453064, "value": -0.222347441992355}, "2": {"effect": 0.00077897246228531, "value": -0.2221845085213706}, "3": {"effect": -0.011097081936895847, "value": -0.2204324169551488}, "4": {"effect": -0.013286489062011242, "value": -0.22235378583056542}, "5": {"effect": -0.013544893823564053, "value": -1.1638377198256806}, "6": {"effect": -0.011932674795389175, "value": -1.1584702546002494}, "7": {"effect": -0.010444951243698597, "value": -1.153104255653234}, "8": {"effect": -0.016126612201333046, "value": -1.580726640890368}, "9": {"effect": -0.0016575180925428867, "value": -1.5615315401908265}, "10": {"effect": -0.0027749433647841215, "value": -1.540589305369299}, "11": {"effect": 7.477440522052348e-05, "value": -1.1935140538762214}, "12": {"effect": -0.0007334616384468973, "value": -1.2012714760573113}, "13": {"effect": -0.0016212740447372198, "value": -1.2083673206332057}, "14": {"effect": -0.046293679624795914, "value": -0.4314066824321592}, "15": {"effect": 0.001761821680702269, "value": -0.5389159935404264}, "16": {"effect": 0.0015864341985434294, "value": -0.507274568588341}, "17": {"effect": 0.001616132096387446, "value": -0.5439101324095778}, "18": {"effect": 0.00523338932543993, "value": -0.5516904477226949}, "19": {"effect": -0.0010191356996074319, "value": -0.06967832368408984}, "20": {"effect": 0.0002884353743866086, "value": -0.06967832368408984}, "21": {"effect": -0.00011417350469855592, "value": -0.06967832368408984}, "22": {"effect": 2.2255157091422006e-05, "value": -0.06967832368408984}, "23": {"effect": -0.00013388284423854202, "value": -0.06967832368408987}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iTM917T2HYQHJ9RJ3XXYP')
#   );
# </script>

# %%
print(f'lstm_metrics: {lstm_metrics}')
print(f'gru_metrics: {gru_metrics}')
print(f'rf_metrics: {rf_metrics}')
print(f'metrics_xgb: {metrics_xgb}')
print(f'persistence_metrics: {persistence_metrics}')
# Out:
# lstm_metrics: {'MAE': 706386.2114906877, 'RMSE': 1784048.4389406382, 'Pearson_Correlation': 0.7795205078593276, 'Spearman_Correlation': 0.7385903346688286, 'Nash_Sutcliffe_Efficiency': 0.5872534965691734, 'Kling_Gupta_Efficiency': 0.6250103636568036, 'RMSE_Extreme': 7277674.594059642}
# gru_metrics: {'MAE': 792628.8532041546, 'RMSE': 1874667.106319894, 'Pearson_Correlation': 0.8000656699425824, 'Spearman_Correlation': 0.7677284601360469, 'Nash_Sutcliffe_Efficiency': 0.5442586467660218, 'Kling_Gupta_Efficiency': 0.7115348311486178, 'RMSE_Extreme': 6787947.605253144}
# rf_metrics: {'MAE': 407707.6995767738, 'RMSE': 1250038.658438315, 'Pearson_Correlation': 0.8994524830695838, 'Spearman_Correlation': 0.8940318684754288, 'Nash_Sutcliffe_Efficiency': 0.7973638117191015, 'Kling_Gupta_Efficiency': 0.7633119512223567, 'RMSE_Extreme': 4864084.649765655}
# metrics_xgb: {'MAE': 569534.4924061605, 'RMSE': 1414932.66934115, 'Pearson_Correlation': 0.8645848804428959, 'Spearman_Correlation': 0.8407333006484867, 'Nash_Sutcliffe_Efficiency': 0.7403778946041149, 'Kling_Gupta_Efficiency': 0.7906370364403479, 'RMSE_Extreme': 5055734.1776766265}
# persistence_metrics: {'MAE': 305148.46155014326, 'RMSE': 1178749.4220559315, 'Pearson_Correlation': 0.9099093188136868, 'Spearman_Correlation': 0.9550894761415593, 'Nash_Sutcliffe_Efficiency': 0.8198172940100977, 'Kling_Gupta_Efficiency': 0.9099092204839632, 'RMSE_Extreme': 4223829.292650395}

# %%
import seaborn as sns
model_metrics = [lstm_metrics, gru_metrics, rf_metrics, metrics_xgb, persistence_metrics]

# Define model names
model_names = ['LSTM', 'GRU', 'RF', 'XGB', 'Persistence']

# Create a DataFrame from the dictionaries
metrics_df = pd.DataFrame(model_metrics, index=model_names)

# Create a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(metrics_df, annot=True, cmap='coolwarm', fmt=".2f", cbar=True, linewidths=0.5)

# Customize the plot
plt.title('Model Comparison: Evaluation Metrics Heatmap')
plt.ylabel('Models')
plt.xlabel('Metrics')

# Show the plot
plt.tight_layout()

# %%
dates_dict_xg['test_dates']
# Out:
# {'train_dates': 5      2000-06-06
#  6      2000-06-07
#  7      2000-06-08
#  8      2000-06-09
#  9      2000-06-10
#            ...
#  3293   2009-06-07
#  3294   2009-06-08
#  3295   2009-06-09
#  3296   2009-06-10
#  3297   2009-06-11
#  Name: date, Length: 3293, dtype: datetime64[ns],
#  'val_dates': 3298   2009-06-12
#  3299   2009-06-13
#  3300   2009-06-14
#  3301   2009-06-15
#  3302   2009-06-16
#            ...
#  3658   2010-06-07
#  3659   2010-06-08
#  3660   2010-06-09
#  3661   2010-06-10
#  3662   2010-06-11
#  Name: date, Length: 365, dtype: datetime64[ns],
#  'test_dates': 3663   2010-06-12
#  3664   2010-06-13
#  3665   2010-06-14
#  3666   2010-06-15
#  3667   2010-06-16
#            ...
#  7148   2019-12-27
#  7149   2019-12-28
#  7150   2019-12-29
#  7151   2019-12-30
#  7152   2019-12-31
#  Name: date, Length: 3490, dtype: datetime64[ns]}
